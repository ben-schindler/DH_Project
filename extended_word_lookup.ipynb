# %%
import re
import pandas as pd
places_csv = pd.read_csv("./data/pleiades-places.csv", 
                        usecols=["path", "id"],
                       index_col="path")
names_csv = pd.read_csv("./data/pleiades-names.csv", 
                        usecols=["title", "pid"]).rename(columns={"pid":"path"})

def save_dict_to_file(dic, path):
    f = open(path,'w')
    f.write(str(dic))
    f.close()

# %%
Places_and_Names= names_csv.join(places_csv, on="path")

# %%
ext_word_lookup ={}
Homonymes = []

for _, row in Places_and_Names.iterrows():
    if row['title'] in ext_word_lookup.keys():
        if row['id'] != ext_word_lookup[row['title']]:
            Homonymes.append(row['title'])
            del ext_word_lookup[row['title']]
    elif row['title'] not in Homonymes:
        ext_word_lookup[row['title']]= row['id']

# %%
len(Homonymes)
# Out:
# 2151

# %%
ext_word_lookup['Argos']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-160-75befaf9c6a4> in <module>()
# ----> 1 ext_word_lookup['Argos']
#
# KeyError: 'Argos'

# %%
herodotus=open('./data/herodotus_history.txt','r',newline='\n').read()
herodotus = herodotus.replace('\n', ' ')
withoutMarks = re.sub(pattern='\W', string=herodotus, repl=" ")
result = re.sub(pattern=' +', string=withoutMarks, repl=" ")
words_in_Herodotus = result.split()

# %%
words_in_Herodotus
# Out:
# ['BOOK',
#  'I',
#  'Clio',
#  'These',
#  'are',
#  'the',
#  'researches',
#  'of',
#  'Herodotus',
#  'of',
#  'Halicarnassus',
#  'which',
#  'he',
#  'publishes',
#  'in',
#  'the',
#  'hope',
#  'of',
#  'thereby',
#  'preserving',
#  'from',
#  'decay',
#  'the',
#  'remembrance',
#  'of',
#  'what',
#  'men',
#  'have',
#  'done',
#  'and',
#  'of',
#  'preventing',
#  'the',
#  'great',
#  'and',
#  'wonderful',
#  'actions',
#  'of',
#  'the',
#  'Greeks',
#  'and',
#  'the',
#  'Barbarians',
#  'from',
#  'losing',
#  'their',
#  'due',
#  'meed',
#  'of',
#  'glory',
#  'and',
#  'withal',
#  'to',
#  'put',
#  'on',
#  'record',
#  'what',
#  'were',
#  'their',
#  'grounds',
#  'of',
#  'feuds',
#  'According',
#  'to',
#  'the',
#  'Persians',
#  'best',
#  'informed',
#  'in',
#  'history',
#  'the',
#  'Phoenicians',
#  'began',
#  'to',
#  'quarrel',
#  'This',
#  'people',
#  'who',
#  'had',
#  'formerly',
#  'dwelt',
#  'on',
#  'the',
#  'shores',
#  'of',
#  'the',
#  'Erythraean',
#  'Sea',
#  'having',
#  'migrated',
#  'to',
#  'the',
#  'Mediterranean',
#  'and',
#  'settled',
#  'in',
#  'the',
#  'parts',
#  'which',
#  'they',
#  'now',
#  'inhabit',
#  'began',
#  'at',
#  'once',
#  'they',
#  'say',
#  'to',
#  'adventure',
#  'on',
#  'long',
#  'voyages',
#  'freighting',
#  'their',
#  'vessels',
#  'with',
#  'the',
#  'wares',
#  'of',
#  'Egypt',
#  'and',
#  'Assyria',
#  'They',
#  'landed',
#  'at',
#  'many',
#  'places',
#  'on',
#  'the',
#  'coast',
#  'and',
#  'among',
#  'the',
#  'rest',
#  'at',
#  'Argos',
#  'which',
#  'was',
#  'then',
#  'preeminent',
#  'above',
#  'all',
#  'the',
#  'states',
#  'included',
#  'now',
#  'under',
#  'the',
#  'common',
#  'name',
#  'of',
#  'Hellas',
#  'Here',
#  'they',
#  'exposed',
#  'their',
#  'merchandise',
#  'and',
#  'traded',
#  'with',
#  'the',
#  'natives',
#  'for',
#  'five',
#  'or',
#  'six',
#  'days',
#  'at',
#  'the',
#  'end',
#  'of',
#  'which',
#  'time',
#  'when',
#  'almost',
#  'everything',
#  'was',
#  'sold',
#  'there',
#  'came',
#  'down',
#  'to',
#  'the',
#  'beach',
#  'a',
#  'number',
#  'of',
#  'women',
#  'and',
#  'among',
#  'them',
#  'the',
#  'daughter',
#  'of',
#  'the',
#  'king',
#  'who',
#  'was',
#  'they',
#  'say',
#  'agreeing',
#  'in',
#  'this',
#  'with',
#  'the',
#  'Greeks',
#  'Io',
#  'the',
#  'child',
#  'of',
#  'Inachus',
#  'The',
#  'women',
#  'were',
#  'standing',
#  'by',
#  'the',
#  'stern',
#  'of',
#  'the',
#  'ship',
#  'intent',
#  'upon',
#  'their',
#  'purchases',
#  'when',
#  'the',
#  'Phoenicians',
#  'with',
#  'a',
#  'general',
#  'shout',
#  'rushed',
#  'upon',
#  'them',
#  'The',
#  'greater',
#  'part',
#  'made',
#  'their',
#  'escape',
#  'but',
#  'some',
#  'were',
#  'seized',
#  'and',
#  'carried',
#  'off',
#  'Io',
#  'herself',
#  'was',
#  'among',
#  'the',
#  'captives',
#  'The',
#  'Phoenicians',
#  'put',
#  'the',
#  'women',
#  'on',
#  'board',
#  'their',
#  'vessel',
#  'and',
#  'set',
#  'sail',
#  'for',
#  'Egypt',
#  'Thus',
#  'did',
#  'Io',
#  'pass',
#  'into',
#  'Egypt',
#  'according',
#  'to',
#  'the',
#  'Persian',
#  'story',
#  'which',
#  'differs',
#  'widely',
#  'from',
#  'the',
#  'Phoenician',
#  'and',
#  'thus',
#  'commenced',
#  'according',
#  'to',
#  'their',
#  'authors',
#  'the',
#  'series',
#  'of',
#  'outrages',
#  'At',
#  'a',
#  'later',
#  'period',
#  'certain',
#  'Greeks',
#  'with',
#  'whose',
#  'name',
#  'they',
#  'are',
#  'unacquainted',
#  'but',
#  'who',
#  'would',
#  'probably',
#  'be',
#  'Cretans',
#  'made',
#  'a',
#  'landing',
#  'at',
#  'Tyre',
#  'on',
#  'the',
#  'Phoenician',
#  'coast',
#  'and',
#  'bore',
#  'off',
#  'the',
#  'king',
#  's',
#  'daughter',
#  'Europe',
#  'In',
#  'this',
#  'they',
#  'only',
#  'retaliated',
#  'but',
#  'afterwards',
#  'the',
#  'Greeks',
#  'they',
#  'say',
#  'were',
#  'guilty',
#  'of',
#  'a',
#  'second',
#  'violence',
#  'They',
#  'manned',
#  'a',
#  'ship',
#  'of',
#  'war',
#  'and',
#  'sailed',
#  'to',
#  'Aea',
#  'a',
#  'city',
#  'of',
#  'Colchis',
#  'on',
#  'the',
#  'river',
#  'Phasis',
#  'from',
#  'whence',
#  'after',
#  'despatching',
#  'the',
#  'rest',
#  'of',
#  'the',
#  'business',
#  'on',
#  'which',
#  'they',
#  'had',
#  'come',
#  'they',
#  'carried',
#  'off',
#  'Medea',
#  'the',
#  'daughter',
#  'of',
#  'the',
#  'king',
#  'of',
#  'the',
#  'land',
#  'The',
#  'monarch',
#  'sent',
#  'a',
#  'herald',
#  'into',
#  'Greece',
#  'to',
#  'demand',
#  'reparation',
#  'of',
#  'the',
#  'wrong',
#  'and',
#  'the',
#  'restitution',
#  'of',
#  'his',
#  'child',
#  'but',
#  'the',
#  'Greeks',
#  'made',
#  'answer',
#  'that',
#  'having',
#  'received',
#  'no',
#  'reparation',
#  'of',
#  'the',
#  'wrong',
#  'done',
#  'them',
#  'in',
#  'the',
#  'seizure',
#  'of',
#  'Io',
#  'the',
#  'Argive',
#  'they',
#  'should',
#  'give',
#  'none',
#  'in',
#  'this',
#  'instance',
#  'In',
#  'the',
#  'next',
#  'generation',
#  'afterwards',
#  'according',
#  'to',
#  'the',
#  'same',
#  'authorities',
#  'Alexander',
#  'the',
#  'son',
#  'of',
#  'Priam',
#  'bearing',
#  'these',
#  'events',
#  'in',
#  'mind',
#  'resolved',
#  'to',
#  'procure',
#  'himself',
#  'a',
#  'wife',
#  'out',
#  'of',
#  'Greece',
#  'by',
#  'violence',
#  'fully',
#  'persuaded',
#  'that',
#  'as',
#  'the',
#  'Greeks',
#  'had',
#  'not',
#  'given',
#  'satisfaction',
#  'for',
#  'their',
#  'outrages',
#  'so',
#  'neither',
#  'would',
#  'he',
#  'be',
#  'forced',
#  'to',
#  'make',
#  'any',
#  'for',
#  'his',
#  'Accordingly',
#  'he',
#  'made',
#  'prize',
#  'of',
#  'Helen',
#  'upon',
#  'which',
#  'the',
#  'Greeks',
#  'decided',
#  'that',
#  'before',
#  'resorting',
#  'to',
#  'other',
#  'measures',
#  'they',
#  'would',
#  'send',
#  'envoys',
#  'to',
#  'reclaim',
#  'the',
#  'princess',
#  'and',
#  'require',
#  'reparation',
#  'of',
#  'the',
#  'wrong',
#  'Their',
#  'demands',
#  'were',
#  'met',
#  'by',
#  'a',
#  'reference',
#  'to',
#  'the',
#  'violence',
#  'which',
#  'had',
#  'been',
#  'offered',
#  'to',
#  'Medea',
#  'and',
#  'they',
#  'were',
#  'asked',
#  'with',
#  'what',
#  'face',
#  'they',
#  'could',
#  'now',
#  'require',
#  'satisfaction',
#  'when',
#  'they',
#  'had',
#  'formerly',
#  'rejected',
#  'all',
#  'demands',
#  'for',
#  'either',
#  'reparation',
#  'or',
#  'restitution',
#  'addressed',
#  'to',
#  'them',
#  'Hitherto',
#  'the',
#  'injuries',
#  'on',
#  'either',
#  'side',
#  'had',
#  'been',
#  'mere',
#  'acts',
#  'of',
#  'common',
#  'violence',
#  'but',
#  'in',
#  'what',
#  'followed',
#  'the',
#  'Persians',
#  'consider',
#  'that',
#  'the',
#  'Greeks',
#  'were',
#  'greatly',
#  'to',
#  'blame',
#  'since',
#  'before',
#  'any',
#  'attack',
#  'had',
#  'been',
#  'made',
#  'on',
#  'Europe',
#  'they',
#  'led',
#  'an',
#  'army',
#  'into',
#  'Asia',
#  'Now',
#  'as',
#  'for',
#  'the',
#  'carrying',
#  'off',
#  'of',
#  'women',
#  'it',
#  'is',
#  'the',
#  'deed',
#  'they',
#  'say',
#  'of',
#  'a',
#  'rogue',
#  'but',
#  'to',
#  'make',
#  'a',
#  'stir',
#  'about',
#  'such',
#  'as',
#  'are',
#  'carried',
#  'off',
#  'argues',
#  'a',
#  'man',
#  'a',
#  'fool',
#  'Men',
#  'of',
#  'sense',
#  'care',
#  'nothing',
#  'for',
#  'such',
#  'women',
#  'since',
#  'it',
#  'is',
#  'plain',
#  'that',
#  'without',
#  'their',
#  'own',
#  'consent',
#  'they',
#  'would',
#  'never',
#  'be',
#  'forced',
#  'away',
#  'The',
#  'Asiatics',
#  'when',
#  'the',
#  'Greeks',
#  'ran',
#  'off',
#  'with',
#  'their',
#  'women',
#  'never',
#  'troubled',
#  'themselves',
#  'about',
#  'the',
#  'matter',
#  'but',
#  'the',
#  'Greeks',
#  'for',
#  'the',
#  'sake',
#  'of',
#  'a',
#  'single',
#  'Lacedaemonian',
#  'girl',
#  'collected',
#  'a',
#  'vast',
#  'armament',
#  'invaded',
#  'Asia',
#  'and',
#  'destroyed',
#  'the',
#  'kingdom',
#  'of',
#  'Priam',
#  'Henceforth',
#  'they',
#  'ever',
#  'looked',
#  'upon',
#  'the',
#  'Greeks',
#  'as',
#  'their',
#  'open',
#  'enemies',
#  'For',
#  'Asia',
#  'with',
#  'all',
#  'the',
#  'various',
#  'tribes',
#  'of',
#  'barbarians',
#  'that',
#  'inhabit',
#  'it',
#  'is',
#  'regarded',
#  'by',
#  'the',
#  'Persians',
#  'as',
#  'their',
#  'own',
#  'but',
#  'Europe',
#  'and',
#  'the',
#  'Greek',
#  'race',
#  'they',
#  'look',
#  'on',
#  'as',
#  'distinct',
#  'and',
#  'separate',
#  'Such',
#  'is',
#  'the',
#  'account',
#  'which',
#  'the',
#  'Persians',
#  'give',
#  'of',
#  'these',
#  'matters',
#  'They',
#  'trace',
#  'to',
#  'the',
#  'attack',
#  'upon',
#  'Troy',
#  'their',
#  'ancient',
#  'enmity',
#  'towards',
#  'the',
#  'Greeks',
#  'The',
#  'Phoenicians',
#  'however',
#  'as',
#  'regards',
#  'Io',
#  'vary',
#  'from',
#  'the',
#  'Persian',
#  'statements',
#  'They',
#  'deny',
#  'that',
#  'they',
#  'used',
#  'any',
#  'violence',
#  'to',
#  'remove',
#  'her',
#  'into',
#  'Egypt',
#  'she',
#  'herself',
#  'they',
#  'say',
#  'having',
#  'formed',
#  'an',
#  'intimacy',
#  'with',
#  'the',
#  'captain',
#  'while',
#  'his',
#  'vessel',
#  'lay',
#  'at',
#  'Argos',
#  'and',
#  'perceiving',
#  'herself',
#  'to',
#  'be',
#  'with',
#  'child',
#  'of',
#  'her',
#  'own',
#  'free',
#  'will',
#  'accompanied',
#  'the',
#  'Phoenicians',
#  'on',
#  'their',
#  'leaving',
#  'the',
#  'shore',
#  'to',
#  'escape',
#  'the',
#  'shame',
#  'of',
#  'detection',
#  'and',
#  'the',
#  'reproaches',
#  'of',
#  'her',
#  'parents',
#  'Whether',
#  'this',
#  'latter',
#  'account',
#  'be',
#  'true',
#  'or',
#  'whether',
#  'the',
#  'matter',
#  'happened',
#  'otherwise',
#  'I',
#  'shall',
#  'not',
#  'discuss',
#  'further',
#  'I',
#  'shall',
#  'proceed',
#  'at',
#  'once',
#  'to',
#  'point',
#  'out',
#  'the',
#  'person',
#  'who',
#  'first',
#  'within',
#  'my',
#  'own',
#  'knowledge',
#  'inflicted',
#  'injury',
#  'on',
#  'the',
#  'Greeks',
#  'after',
#  'which',
#  'I',
#  'shall',
#  'go',
#  'forward',
#  'with',
#  'my',
#  'history',
#  'describing',
#  'equally',
#  'the',
#  'greater',
#  'and',
#  'the',
#  'lesser',
#  'cities',
#  'For',
#  'the',
#  'cities',
#  'which',
#  'were',
#  'formerly',
#  'great',
#  'have',
#  'most',
#  'of',
#  'them',
#  'become',
#  'insignificant',
#  'and',
#  'such',
#  'as',
#  'are',
#  'at',
#  'present',
#  'powerful',
#  'were',
#  'weak',
#  'in',
#  'the',
#  'olden',
#  'time',
#  'I',
#  'shall',
#  'therefore',
#  'discourse',
#  'equally',
#  'of',
#  'both',
#  'convinced',
#  'that',
#  'human',
#  'happiness',
#  'never',
#  'continues',
#  'long',
#  'in',
#  'one',
#  'stay',
#  'Croesus',
#  'son',
#  'of',
#  'Alyattes',
#  'by',
#  'birth',
#  'a',
#  'Lydian',
#  'was',
#  'lord',
#  'of',
#  'all',
#  'the',
#  'nations',
#  'to',
#  'the',
#  'west',
#  'of',
#  'the',
#  'river',
#  'Halys',
#  'This',
#  'stream',
#  'which',
#  'separates',
#  'Syria',
#  'from',
#  'Paphlagonia',
#  'runs',
#  'with',
#  'a',
#  'course',
#  'from',
#  'south',
#  'to',
#  'north',
#  'and',
#  'finally',
#  'falls',
#  'into',
#  'the',
#  'Euxine',
#  'So',
#  'far',
#  'as',
#  'our',
#  'knowledge',
#  'goes',
#  'he',
#  'was',
#  'the',
#  'first',
#  'of',
#  'the',
#  'barbarians',
#  'who',
#  ...]

# %%
critical_words = {}
for word in words_in_Herodotus:
    if word in Homonymes:
        if word not in critical_words:
            critical_words[word] =1
        else:
            critical_words[word] +=1

# %%
len(critical_words)
# Out:
# 130

# %%
print(critical_words)
# Out:
# {'Assyria': 11, 'Argos': 17, 'Europe': 45, 'Colchis': 3, 'Phasis': 8, 'Asia': 95, 'Syria': 21, 'Paphlagonia': 1, 'Ionia': 49, 'Lydia': 16, 'Belus': 3, 'Phrygia': 8, 'Smyrna': 7, 'Colophon': 3, 'Scythia': 60, 'Chios': 19, 'Arion': 8, 'Eleusis': 6, 'Olympus': 4, 'Dodona': 7, 'Ossa': 1, 'Attica': 28, 'Eretria': 17, 'Naxos': 14, 'Delos': 17, 'Tegea': 9, 'Alea': 1, 'Samos': 57, 'Cappadocia': 4, 'Armenia': 9, 'Cilicia': 11, 'Cyprus': 19, 'Babylon': 33, 'Pteria': 3, 'Sinope': 4, 'Thyrea': 5, 'Malea': 2, 'Meles': 2, 'Caria': 7, 'Teos': 4, 'Pentapolis': 1, 'Cos': 1, 'Cnidus': 4, 'Pellene': 1, 'Dyme': 1, 'Larissa': 1, 'Myrina': 2, 'Tenedos': 4, 'Sacae': 3, 'Mysia': 3, 'Corsica': 1, 'Abdera': 4, 'Sardinia': 4, 'Lycus': 3, 'Syme': 1, 'Patara': 2, 'Choaspes': 4, 'Susa': 32, 'Tigris': 6, 'Araxes': 9, 'Memphis': 40, 'Heliopolis': 10, 'Pisa': 2, 'Teuthrania': 1, 'Achelous': 1, 'Arabia': 19, 'Thebais': 2, 'Apis': 13, 'Meroe': 1, 'Cyrene': 30, 'Soloeis': 2, 'Mendes': 3, 'Thasos': 6, 'Samothrace': 2, 'Pelasgia': 1, 'Papremis': 5, 'Neapolis': 1, 'Nysa': 2, 'Elis': 8, 'Tanis': 1, 'Athribis': 1, 'Aegyptus': 1, 'Corcyra': 7, 'Borysthenes': 18, 'Tyras': 5, 'Bosphorus': 13, 'Proconnesus': 5, 'Issedones': 1, 'Hypanis': 12, 'Tanais': 12, 'Tenos': 2, 'Andros': 2, 'Indus': 1, 'Artanes': 1, 'Rhodope': 1, 'Apollonia': 2, 'Agrianes': 1, 'Abydos': 3, 'Sestos': 1, 'Thera': 15, 'Platea': 10, 'Salamis': 7, 'Aphrodisias': 1, 'Macae': 1, 'Gindanes': 2, 'Triton': 7, 'Zacynthus': 2, 'Macedonia': 6, 'Paros': 4, 'Heraclea': 1, 'Eryx': 1, 'Sybaris': 4, 'Minoa': 1, 'Selinus': 1, 'Tanagra': 2, 'Megara': 1, 'Petra': 2, 'Acheron': 1, 'Anthemus': 1, 'Chersis': 2, 'Marsyas': 2, 'Mylasa': 1, 'Leros': 2, 'Didyma': 1, 'Gela': 1, 'Polichne': 1, 'Melas': 1, 'Hyle': 1, 'Siris': 1, 'Hermione': 1}

# %%
# Out:
# ['Ebusus',
#  'Maenuba',
#  'Mainake',
#  'Malaca',
#  'Saetabis',
#  'Sucro',
#  'Toledo',
#  'Egelesta',
#  'Ucia',
#  'Salaria',
#  'Salduba',
#  'Col. Iulia Valentia Banasa',
#  'Heras',
#  'Lixus',
#  'Tamuda',
#  'Zilil',
#  'Akra',
#  'Mina',
#  'Siga',
#  'Tasaccora',
#  'Bam',
#  'Oppidum Novum',
#  'Zranka',
#  'Gedrosia',
#  'Phrada',
#  'Phra',
#  'Farah',
#  'Zarang',
#  'Fasā',
#  'Kermān',
#  'Yazd',
#  'Akouensioi',
#  'Kophanta',
#  'Sabis',
#  'Ad Rubras',
#  'Calama',
#  'Caput Amsagae',
#  'Strophades',
#  'Cavares',
#  'Fossae Marianae',
#  'Forum Neronis',
#  'Constantina',
#  'Reii',
#  'Arabia',
#  'Babylonia',
#  'Basra',
#  'Eridu Ǧanūb',
#  'Eridu Šimāl',
#  'Eridu',
#  'Purattu',
#  'Euphrates',
#  'Ohurmazd-Artaḫšēr',
#  'Alexandria',
#  'Larsa',
#  'Nippur',
#  'Pasitigris',
#  'Eulaeus',
#  'Susa',
#  'Šūš',
#  'Forum Iulium',
#  'Macae',
#  'Rapsa',
#  'Ad Turrem',
#  'Aspis',
#  'Arae Philaenorum',
#  'Chosol',
#  'Musula',
#  'Chersis',
#  'Cyrene',
#  'Euesperides',
#  'Hesperidum Horti',
#  'Olbia',
#  'Plateia',
#  'Cherronesos',
#  'Chersonesos Akra',
#  'Disthis',
#  'Ad Fines',
#  'Ad X',
#  'Duria',
#  'Forum Novum',
#  'Hasta',
#  'Iria',
#  'Libicii',
#  'Parma',
#  'Pollentia',
#  'Stura',
#  'Tegulata',
#  'Quadrata',
#  'Arsinoe',
#  'Azania',
#  'Badis',
#  'Ad IX',
#  'Ad Medias',
#  'Ad Novas',
#  'Ad Portum',
#  'Meduacus Maior',
#  'Meduacus Minor',
#  'Septem Maria',
#  'Saba',
#  'Sabatha',
#  'Olympos M.',
#  'Pergamon',
#  'Bergama',
#  'Psyra',
#  'Hadrianopolis',
#  'Tenedos',
#  'Tmolos',
#  'Halai',
#  'Antiochia',
#  'Theodosiopolis',
#  'Itone',
#  'Koloe',
#  'Mandrai',
#  'Ollius',
#  'Panda',
#  'Parthenion',
#  'Polichna',
#  'Polichne',
#  'Sipylos',
#  'Xanthos',
#  'Achaia',
#  'Aigila',
#  'Arachnaion',
#  'Argos',
#  'Pelasgia',
#  'Aroanios',
#  'Artemis Limnatis, T.',
#  'Asine',
#  'Asopos',
#  'Asterion',
#  'Astron',
#  'Athenaion',
#  'Belbina',
#  'Charadros',
#  'Aigialos',
#  'Hira',
#  'Ira',
#  'Elis',
#  'Erymanthos',
#  'Eurotas',
#  'Helike',
#  'Helisson',
#  'Heraion',
#  'Isthmos',
#  'Erechtheion',
#  'Ouxella',
#  'Acheron',
#  'Aiginetes',
#  'Amastris',
#  'Assyria',
#  'Claudiopolis',
#  'Bolu',
#  'Bithynion',
#  'Elaios',
#  'Heraclea',
#  'Hieros',
#  'Kales',
#  'Oxinas',
#  'Kieros',
#  'Teuthrania',
#  'Hermonassa',
#  'Nymphaion',
#  'Kaisareia',
#  'Apollonia',
#  'Phanagoreia',
#  'Phanagoria',
#  'Dia',
#  'Herakleion',
#  'Kimmerikon',
#  'Zephyrion',
#  'Sagarenoi',
#  'Sala',
#  'Aydın',
#  'Tralleis',
#  'Seleukeia',
#  'Balgatia',
#  'Anqara',
#  'Korama',
#  'Modicus M.',
#  'Therma',
#  'Proseilemmene',
#  'Klaudiopolis',
#  'Tetrapyrgia',
#  'Charax',
#  'Chryse',
#  'Dasmenda',
#  'Euagina',
#  'Korax',
#  'Mazaka',
#  'Caesarea',
#  'Melas',
#  'Melitene',
#  'Malatja',
#  'Malaṭya',
#  'Omma',
#  'Saraouene',
#  'Sivas',
#  'Sebasteia',
#  'Sīwās',
#  'Koloneia',
#  'In Medio',
#  'Borissos',
#  'Euaissa',
#  'Siva',
#  'Kanotala',
#  'Apamea',
#  'Aphrodisias',
#  'Apollonia',
#  'Arykanda',
#  'Aspis',
#  'Anṭāliyā',
#  'Baris',
#  'Isparta',
#  'İsparta',
#  'Glaukos',
#  'Hadrianopolis',
#  'Hadriani',
#  'Hiera Akra',
#  'Hierapolis',
#  'Idyros',
#  'Isinda',
#  'Diokaisareia',
#  'Klimax',
#  'Diospolis',
#  'Limnai',
#  'Lissa',
#  'Malos',
#  'Megiste',
#  'Neapolis',
#  'Olympus',
#  'Patara',
#  'Burdur',
#  'Ptolemais',
#  'Aulutrene',
#  'Sebastopolis',
#  'Seleucia',
#  'Side',
#  'Strongyle',
#  'Antoniopolis',
#  'Xanthos',
#  'Civitas Cillanensium',
#  'Eudokias',
#  'Naustathmos',
#  'Caena',
#  'Ophis',
#  'Patara',
#  'Phasis',
#  'Side',
#  'Psychros',
#  'Pteria',
#  'Rize',
#  'Rhizaion',
#  'Sinope',
#  'Talaura',
#  'Trapezous',
#  'Tripolis',
#  'Siganeon',
#  'Tagisken',
#  'Oescus',
#  'Praetorium',
#  'Malva',
#  'Sucidava',
#  'Troglodytae',
#  'Utus',
#  'Beripara',
#  'Markerota',
#  'Mediolanum',
#  'Orkelis',
#  'Therma',
#  'Borysthenes',
#  'Olbia',
#  'Chersonesos',
#  'Istros',
#  'Hierasos',
#  'Achilleios Dromos',
#  'Satauci',
#  'Taphros',
#  'Krym',
#  'Skythotauroi',
#  'Tyras',
#  'Akra',
#  'Argoda',
#  'Chalkis',
#  'Parosta',
#  'Satarche',
#  'Tabana',
#  'Tamasidaua',
#  'Tarona',
#  'Tazos',
#  'Teos',
#  'Zargidaua',
#  'Aquae Calidae',
#  'Kār-Tukultī-Ninurta',
#  'Mauretania Tingitana',
#  'Skylax',
#  'Petra',
#  'Salassi',
#  'Thapsus',
#  'Tipasa',
#  'Tucca',
#  'Ad Dracones',
#  'Ad Ficum',
#  'Ad Palmam',
#  'Capraria',
#  'Giddaba M.',
#  'Zarath',
#  'Ad Aquas',
#  'Ad Mercurium',
#  'Carpi',
#  'Neapolis',
#  'Pagus Muxsi',
#  'Apollinis Pr.',
#  'Thibiuca',
#  'Ucubi',
#  'Vicus Augusti',
#  'Namara',
#  'Berenice',
#  'Philippopolis',
#  'Samaria',
#  'Sebaste',
#  'Nysa',
#  'Seleukeia',
#  'ṣdn',
#  'Ṣaidā',
#  'Ṣidon',
#  'Sidon',
#  'Caifas',
#  'Ṣor',
#  'Tyrus',
#  'Castra Samaritanorum',
#  'Diospolis',
#  'Leontopolis',
#  'Neapolis',
#  'Archelais',
#  'Ašqǝlon',
#  'Isqalūna',
#  'Ascalon',
#  'Pella',
#  'Nicopolis',
#  'ʿAzzȧ',
#  'Gaza',
#  'Ḫazzatu',
#  'Constantia',
#  'Arīḥā',
#  'Hierichous',
#  'Yǝriḥo',
#  'Jericho',
#  'Ursalimmu',
#  'Jerusalem',
#  'Hierosolyma',
#  'Yǝrušȧlayim',
#  'Yāfā',
#  'Yȧfo',
#  'Jaffa',
#  'ha-Yardẹn',
#  'Maon',
#  'al-ʿArīš',
#  'Socho',
#  'Thekoa',
#  'Alauna',
#  'Aregenoua',
#  'Osismii',
#  'Sena',
#  'Petra',
#  'Petra',
#  'Philadelpheia',
#  'Bīt-Ammāna',
#  'Tyrus',
#  'Calamona',
#  'Aphrodision',
#  'Apollo, T.',
#  'Apollo, T.',
#  'Arsinoe',
#  'Arsinoe',
#  'Drepanon Pr.',
#  'Drepanon',
#  'Hiera',
#  'Qarth.adašt',
#  'Leukousia',
#  'Nicosia',
#  'Lykos',
#  'Neapolis',
#  'Nymphaion',
#  'Olympos M.',
#  'Olympos',
#  'Paphos',
#  'Pedalion Pr.',
#  'Phrourion',
#  'Dades Pr.',
#  'Zephyrion',
#  'Asine',
#  'Argos',
#  'Corinaeum',
#  'Erythrai',
#  'Kyrnos',
#  'Lapethos',
#  'Palaia',
#  'Pegai',
#  'Tegessos',
#  'Apis',
#  'Tetrapyrgia',
#  'Kardamis',
#  'Klimax',
#  'Pedonia',
#  'Zephyrion Akron',
#  'Zephyrion Pr.',
#  'Zeszes',
#  'Oasis Parva',
#  'Zygris',
#  'Bassachis regio',
#  'Gareathis regio',
#  'Septimiake regio',
#  'Alexandria',
#  'Alexandreia',
#  'Athribis',
#  'Babylon',
#  'Bolbitinon Stoma',
#  'Bouto',
#  'Heliopolis',
#  'Hermou polis',
#  'Isieion',
#  'Iuliopolis',
#  'Leontopolis',
#  'Neilos',
#  'Nitriai',
#  'Pikrai Limnai',
#  'Pseudostoma',
#  'Sebennytikon Stoma',
#  'Leuke Akte',
#  'Karyai',
#  'Kaukones',
#  'Kenchreai',
#  'Keryneia',
#  'Kleitor',
#  'Arsinoe',
#  'Korone',
#  'Kromna',
#  'Kyllene',
#  'Kyparissia',
#  'Tel-Aviv',
#  'Ṭel Aviv-Yȧfo',
#  'Balāwāt',
#  ' Chimo',
#  'Diospolis',
#  'Papremis',
#  'Phernouphis',
#  'Syron',
#  'Bousiris',
#  'Shusha',
#  'Dionysias',
#  'Herakleopolis',
#  'Arsinoe',
#  'Arsinoē',
#  'Ptolemais Euergetis',
#  'Kynopolis',
#  'Memphis',
#  'Memphites Nomos',
#  'Parembole',
#  'Psobthis',
#  'Serapeum',
#  'Spania',
#  'Tanis',
#  'al-Minyā',
#  'Thallou',
#  'Neiloupolis',
#  'Tomis',
#  'Theodosioupolis',
#  'Troikon Oros',
#  'Eleusis',
#  'Herakleia',
#  'Herakleion',
#  'Hiera Nesos',
#  'Ibion',
#  'Kaine',
#  'Mendes',
#  'Mouchis',
#  'Pakerke',
#  'Pelousion',
#  'Philoteris',
#  'Sebennytos',
#  'Tholthis',
#  'Tholthis',
#  'Toou',
#  'Ailana',
#  'Berenike',
#  'Aila',
#  'Aila',
#  'Ad Dianam',
#  'Gypsaria',
#  'Phoinikon',
#  'Poseideion',
#  'Sarakene',
#  'Syna M.',
#  'Apa Apollo, Mon.',
#  'Aphroditopolis',
#  'Aphroditopolites Nomos',
#  'Apollonopolites Nomos',
#  'Bousiris',
#  'Diospolites Nomos',
#  'Tell el-Balamun',
#  'Hermopolites Nomos',
#  'Hypsele',
#  'Kleopatris',
#  'Lykopolis',
#  'El-Ashmunein',
#  'Ammonos',
#  'Areos Kome',
#  'Kerkethoeris',
#  'Ophis',
#  'Terythis',
#  'Melainai',
#  'Pithos',
#  'Ampelos',
#  'Andros',
#  'Apollonia',
#  'Apollonia',
#  'Athena, T.',
#  'Aulon',
#  'Chalke',
#  'Chalcia',
#  'Didymoi',
#  'Elektra',
#  'Gortyna',
#  'Larissa',
#  'Hieron',
#  'Inatos',
#  'Kamiros',
#  'Kantanos',
#  'Kasos',
#  'Katarraktes',
#  'Kaudos',
#  'Keraia',
#  'Kimolos',
#  'Kisamos',
#  'Kriou Metopon Pr.',
#  'Apollonia',
#  'Kytaion',
#  'Larisa',
#  'Leuke',
#  'Massalia',
#  'Minoa',
#  'Naulochos',
#  'Panormos',
#  'Phoinix',
#  'Pholegandros',
#  'Polichna',
#  'Pyrra',
#  'Rhizenia',
#  'Rhodos',
#  'Saros',
#  'Seriphos',
#  'Sikinos',
#  'Syros',
#  'Tarra',
#  'Tenos',
#  'Zagora',
#  'Zephyrion Pr.',
#  'Boiai',
#  'Daidala',
#  'Harmedon',
#  'Hierapolis',
#  'Maroneia',
#  'Strongyle',
#  'Aipeia',
#  'Argos',
#  'Alexandria',
#  'Alexandropolis',
#  'Alexandreia en Arachōsia',
#  'Arbis',
#  'Arachosia',
#  'Alexandria',
#  'Arachotos',
#  'Demetrias',
#  'Choaspes',
#  'Cyreschata',
#  'Padus',
#  'Gaza',
#  'Hypanis',
#  'Silis',
#  'Tanais',
#  'Indus',
#  'Phison',
#  'Issedones',
#  'Kophen',
#  'Kābul',
#  'Maleus M.',
#  'Nagara',
#  'Dionysopolis',
#  'Nikaia',
#  'Anaphe',
#  'Apollo, T.',
#  'Arethousa',
#  'Aspis',
#  'Arkonnesos',
#  'Astypalaia',
#  'Chersonesos',
#  'Cnidus',
#  'Colophon',
#  'Delion',
#  'Delos',
#  'Dia',
#  'Didyma',
#  'Elaioussa',
#  'Ephesus',
#  'Herakleion',
#  'Hiera',
#  'Iasos',
#  'Ios',
#  'Kallipolis',
#  'Araxes',
#  'Karyanda',
#  'Korsiai',
#  'Kos',
#  'Kressa',
#  'Kynthos M.',
#  'Orobis',
#  'Lepsia',
#  'Leros',
#  'Lethaios',
#  'Marsyas',
#  'Melas',
#  'Balat',
#  'Minoa',
#  'Mykonos',
#  'Mylasa',
#  'Naulochos',
#  'Naxos',
#  'Nisyros',
#  'Caucasus M.',
#  'Oia',
#  'Oinoe',
#  'Palaiapolis',
#  'Panormos',
#  'Panormos',
#  'Panormos',
#  'Panormos',
#  'Bargasa',
#  'Paros',
#  'Patmos',
#  'Pele',
#  'Patala',
#  'Phoinix',
#  'Pedasa',
#  'Pentapolis',
#  'Poseidon, T.',
#  'Karana',
#  'Balıkesir',
#  'Helos',
#  'Herakleia',
#  'Hierakome',
#  'Hippoi',
#  'Hyllos',
#  'Ida M.',
#  'Troia',
#  'Kane',
#  'Kanai',
#  'Kardamyle',
#  ' Kilbianoi',
#  'Kissos',
#  'Kisthene',
#  'Klazomenai',
#  'Kolonai',
#  'Larisa',
#  'Ptolemais',
#  'Leukai',
#  'Flaviopolis',
#  'Lyrnessos',
#  'Maionia',
#  'Melaina Pr.',
#  'Meles',
#  'Meter Theon, T.',
#  'Metropolis',
#  'Miletos',
#  'Myrina',
#  'Sebastopolis',
#  'Mysia',
#  'Maltepe',
#  'Nakrason',
#  'Smyrna',
#  'İzmir',
#  'Acerrae',
#  'Ad Flexum',
#  'Ad Rotas',
#  'Astura',
#  'Atina',
#  'Beneventum',
#  'Capreae',
#  'Capri',
#  'Herculaneum',
#  'Nesis',
#  'Nuceria',
#  'Oplontis',
#  'Neapolis',
#  'Pithekoussai',
#  'Pompei',
#  'Pontia',
#  'Saepinum',
#  'Savo',
#  'Sora',
#  'Speluncae',
#  'Fossa Neronis',
#  'Ad Novas',
#  'Aequanus Pagus',
#  'Alfaterni',
#  'Casilinum',
#  'Cliternia',
#  'Ferentinum',
#  'Minturnae',
#  'Sabata',
#  'Sirpium',
#  'Sulmo',
#  'Velia',
#  'Vicus Palatius',
#  'Ad Decimum',
#  'Ad Silarum',
#  'Ad Speluncas',
#  'Aquilonia',
#  'Argos Hippium',
#  'Aufidena',
#  'Caelia',
#  'Athenaion',
#  'Gerounion',
#  'Grumentum',
#  'Hales',
#  'Hera, T.',
#  'Hyria',
#  'Leuca',
#  'Planisium',
#  'Paestum',
#  'Salapia',
#  'Salpiai',
#  'Salapiai',
#  'Salpia',
#  'Albendin',
#  'Kars',
#  'Xanthos',
#  'Aidepsos',
#  'Aigai',
#  'Akrai',
#  'Alope',
#  'Anthedon',
#  'Antikyra',
#  'Apidanos',
#  'Apollo, T.',
#  'Apollo, T.',
#  'Apollo, T.',
#  'Argoura',
#  'Artemision',
#  'Asopos',
#  'Attaleia',
#  'Boion',
#  'Boumeliteia',
#  'Chaeronea',
#  'Chersonesos Pr.',
#  'Demeter, T.',
#  'Dion',
#  'Doris',
#  'Elateia',
#  'Enipeus',
#  'Erineos',
#  'Erythrai',
#  'Hyle',
#  'Hysiai',
#  'Inachos',
#  'Itonion',
#  'Kallipolis',
#  'Koralios',
#  'Ephyra',
#  'Kresion',
#  'Krounoi',
#  'Larissa',
#  'Larymna',
#  'Makra Kome',
#  'Medeon',
#  'Mylai',
#  'Nikaia',
#  'Oichalia',
#  'Phalanna',
#  'Pamisos',
#  'Panormos',
#  'Parthenion',
#  'Skopelos',
#  'Phalika',
#  'Polyaigos',
#  'Pteleon',
#  'Herakles, T.',
#  'Schedia',
#  'Tymphaia',
#  'Herakleia',
#  'Aia',
#  'Akra',
#  'Akragas',
#  'Apollonia',
#  'Arakynthos M.',
#  'Asklepios, T.',
#  'Aulon',
#  'Boibe',
#  'Cereus',
#  'Drymos',
#  'Drymaia',
#  'Dyme',
#  'Ellopia',
#  'Hellopia',
#  'Eurymenai',
#  'Euthia',
#  'Graia',
#  'Herakleion',
#  'Histiaia',
#  'Ichnai',
#  'Achnai',
#  'Ionia',
#  'Kleonai',
#  'Koroneia',
#  'Kyra',
#  'Leon',
#  'Meliboia',
#  'Menelais',
#  'Metropolis',
#  'Myrmex',
#  'Nesos',
#  'Nisa',
#  'Oichalia',
#  'Ormenion',
#  'Petra',
#  'Poseidion',
#  'Pyrrha',
#  'Stephane',
#  'Achaion Limen',
#  'Acheloos',
#  'Achilleion',
#  'Aeolis',
#  'Antissa',
#  'Apollonis',
#  'Asklepieion',
#  'Apollonia',
#  'Astyra',
#  'Andeira',
#  'Attea',
#  'Axos',
#  'Birytis',
#  'Chalkis',
#  'Charax',
#  'Chios',
#  'Delphinion',
#  'Dios Hieron',
#  'Dotion',
#  'Elaea',
#  'Erythrai',
#  'Euenos',
#  'Gentinos',
#  'Glaukos',
#  'Koloe',
#  'Lykastos',
#  'Mardara',
#  'Megara',
#  'Melas',
#  'Phanoria',
#  'Stabulum',
#  'Aia',
#  'Amasya',
#  'Amaseia',
#  'Samsun',
#  'Andrapa',
#  'Neapolis',
#  'Valentia',
#  'Apsaros',
#  'Arauraka',
#  'Argyria',
#  'Euripos',
#  'Harpasos',
#  'Chadisia',
#  'Dasteira',
#  'Eupatoria',
#  'Glaukos',
#  'Kyaneos',
#  'Gyenos',
#  'Halys',
#  'Hieron Oros',
#  'Hippos',
#  'Hyssos',
#  'Kerasous',
#  'Kerasous',
#  'Gerasus',
#  'Giresun',
#  'Pharnakeia',
#  'Kerasount',
#  'Kissa',
#  'Kyptasia',
#  'Herakleion',
#  'Laodikeia',
#  'Lykos',
#  'Gayl',
#  'Lūkīya',
#  'Kelkit',
#  'Kelkit Çayı',
#  'Denizli',
#  'Via Popilia',
#  'Flavias',
#  'Ḳarṣ',
#  'Regia',
#  'Samosata',
#  'Singa',
#  'Symeon, Mon.',
#  'Erana',
#  'Ladon',
#  'Orientalium, Mon.',
#  'Madnhaye, Mon.',
#  'Ebabbar',
#  'Aemilia',
#  'Helorus',
#  'Henna',
#  'Hiera',
#  'Maritima',
#  'Himera',
#  'Himeras',
#  'Hippana',
#  'Hybla',
#  'Hykkara',
#  'Hypsas',
#  'Kakyron',
#  'Kasmenai',
#  'Lipara',
#  'Lykos',
#  'Mazara',
#  'Melita',
#  'Morgantina',
#  'Motya',
#  'Myttistraton',
#  'Naulochos',
#  'Naxos',
#  'Naxus',
#  'Netum',
#  'Ortygia',
#  'Phintias',
#  'Phoinikous Limen',
#  'Phoinix',
#  'Segesta',
#  'Selinous',
#  'Selinus',
#  'Sicani',
#  'Solous',
#  'Soloeis',
#  'Athenaion',
#  'Traiectus',
#  'Tyndaris',
#  'Tindari',
#  'Achilleion',
#  'Aterion',
#  'Chersonesos Pr.',
#  'Emporion',
#  'Herakleia',
#  'Herbessos',
#  'Ina',
#  'Kalauria',
#  'Krastos',
#  'Kydonia',
#  'Kyme',
#  'Leton',
#  'Lissos',
#  'Motyon',
#  'Nea',
#  'Neapolis',
#  'Polichne',
#  'Simoeis',
#  'Skamandros',
#  'Symaethus',
#  'Ad Medias',
#  'Ad Octavum',
#  'Hermaia',
#  'Zippalanda',
#  'Myle',
#  'Iustinianopolis',
#  'Thyessos',
#  'Adana',
#  'Adana',
#  'Adana',
#  'Aphrodisias',
#  'Arima',
#  'Arsinoe',
#  'Augusta',
#  'Augustopolis',
#  'Thebae',
#  'Aulai',
#  'Charadros',
#  'Derbe',
#  'Diocaesarea',
#  'Elaioussa',
#  'Sebaste',
#  'Hyde',
#  'Ikonium',
#  'Kestros',
#  'Krambousa',
#  'Lamos',
#  'Laranda',
#  'Mallos',
#  'Antiochia ad Pyramum',
#  'Melas',
#  'Mylai',
#  'Myous',
#  'Col. Iulia Augusta Felix',
#  ...]

# %%
for i, row in Places_and_Names.iterrows():
    if row['title']=='Hellas':
        print(row['id'])
# Out:
# 1001896
# 1001896

# %%
save_dict_to_file(ext_word_lookup, "./data/word_lookup.txt")

# %%
# Out:
# jo

# %%
# Out:
# jo
# jo
# jo
# jo
