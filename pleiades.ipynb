# %% [markdown]
# ## Getting started
# First let's load the pleiades data from our repository using the pandas package.
# The 'usecols' parameter selects wich columns we load into python.

# %%
import re
import pandas as pd
import numpy as np
import json
datatable = pd.read_csv("./data/pleiades-places.csv", 
                        usecols=["authors", "title", "id", "description", "featureTypes", 
                                 "reprLat", "reprLong", "path","timePeriodsKeys", "timePeriodsRange", "minDate", "maxDate"],
                       index_col="id")

def load_dict_from_file(path):
    f = open(path,'r')
    data=f.read()
    f.close()
    return eval(data)

# %% [markdown]
# Now let's have a look at our imported datatable:

# %%
datatable
# Out:
#                                                      authors  \
# id
# 48210385                              Becker, J., T. Elliott
# 48210386                              Becker, J., T. Elliott
# 265876     Spann, P., DARMC, R. Talbert, S. Gillies, R. W...
# 265877     Spann, P., R. Warner, R. Talbert, S. Gillies, ...
# 265878     Spann, P., R. Warner, R. Talbert, T. Elliott, ...
# 265880     Spann, P., J. Becker, DARMC, T. Elliott, S. Gi...
# 265882     Spann, P., R. Warner, R. Talbert, T. Elliott, ...
# 265883     Spann, P., DARMC, R. Talbert, R. Warner, J. Be...
# 265884     Spann, P., R. Warner, R. Talbert, S. Gillies, ...
# 265886     Spann, P., DARMC, R. Talbert, J. Becker, R. Wa...
# 265887     Spann, P., J. Becker, DARMC, T. Elliott, S. Gi...
# 265888     Spann, P., R. Warner, R. Talbert, S. Gillies, ...
# 265890     Spann, P., DARMC, R. Talbert, J. Becker, R. Wa...
# 265891     Spann, P., DARMC, R. Talbert, J. Becker, R. Wa...
# 265893     Spann, P., R. Warner, R. Talbert, T. Elliott, ...
# 265894     Spann, P., DARMC, R. Talbert, R. Warner, J. Be...
# 265896     Spann, P., DARMC, R. Talbert, R. Warner, J. Be...
# 265897     Spann, P., R. Warner, R. Talbert, S. Gillies, ...
# 265898     Spann, P., R. Warner, R. Talbert, T. Elliott, ...
# 265899     Spann, P., DARMC, R. Talbert, J. Becker, R. Wa...
# 265900     Spann, P., DARMC, R. Talbert, J. Becker, R. Wa...
# 265901     Spann, P., R. Warner, R. Talbert, T. Elliott, ...
# 265902     Spann, P., R. Warner, R. Talbert, T. Elliott, ...
# 265903     Spann, P., R. Warner, R. Talbert, T. Elliott, ...
# 265905     Spann, P., DARMC, R. Talbert, J. Becker, R. Wa...
# 265906     Spann, P., DARMC, R. Talbert, R. Warner, J. Be...
# 265914     Spann, P., DARMC, R. Talbert, J. Becker, R. Wa...
# 265916     Spann, P., DARMC, R. Talbert, R. Warner, J. Be...
# 265917     Spann, P., R. Warner, R. Talbert, T. Elliott, ...
# 265919     Spann, P., DARMC, R. Talbert, R. Warner, J. Be...
# ...                                                      ...
# 963101396                      DARMC, S. Gillies, T. Elliott
# 963101397                      DARMC, S. Gillies, T. Elliott
# 963101398                      DARMC, S. Gillies, T. Elliott
# 963101399                      DARMC, S. Gillies, T. Elliott
# 963101400                      DARMC, S. Gillies, T. Elliott
# 963101401                      DARMC, S. Gillies, T. Elliott
# 963101402                      DARMC, S. Gillies, T. Elliott
# 963101403                      DARMC, S. Gillies, T. Elliott
# 963101404                      DARMC, S. Gillies, T. Elliott
# 963101405                      DARMC, S. Gillies, T. Elliott
# 963101406                      DARMC, S. Gillies, T. Elliott
# 963101407                      DARMC, S. Gillies, T. Elliott
# 963101408                      DARMC, S. Gillies, T. Elliott
# 963101409                      DARMC, S. Gillies, T. Elliott
# 973204925     Varveri, A., J. Becker, E. Robinson, V. Vitale
# 732014845                                         Becker, J.
# 32331671                                Becker, J., R. Horne
# 32331672                                Becker, J., R. Horne
# 689737510                                         Becker, J.
# 689737511                               Becker, J., R. Horne
# 689737512                                Becker, J., G. Moss
# 858265770                                         Becker, J.
# 416269079                             Becker, J., T. Elliott
# 6525101                                           Becker, J.
# 721382239                               Becker, J., R. Horne
# 721382240                                         Becker, J.
# 893850615                                         Becker, J.
# 535296216                             Becker, J., T. Elliott
# 233061794                             Becker, J., T. Elliott
# 743134062                             Becker, J., T. Elliott
#
#                                                  description  featureTypes  \
# id
# 48210385   The post-Roman settlement at Alba Fucens becam...    settlement
# 48210386   A major urban sanctuary at Vulci with a long p...      temple-2
# 265876     An ancient settlement, likely of Celtic origin...    settlement
# 265877     An ancient place, cited: BAtlas 27 D3 Contestania        region
# 265878     An ancient place, cited: BAtlas 27 C4 Cueva de...          mine
# 265880     An ancient place, cited: BAtlas 27 F3 Dianium/...    settlement
# 265882           An ancient place, cited: BAtlas 27 B4 Ebura    settlement
# 265883          An ancient place, cited: BAtlas 27 G3 Ebusus    settlement
# 265884     Ebusus Ins. (modern Ibiza) is an island in the...        island
# 265886           An ancient place, cited: BAtlas 27 B3 Edeba    settlement
# 265887     An ancient place, cited: BAtlas 27 E2 Edeta/Le...    settlement
# 265888        An ancient place, cited: BAtlas 27 E2 Edetania        region
# 265890     An ancient place, cited: BAtlas 27 C3 Elche de...    settlement
# 265891      An ancient place, cited: BAtlas 27 D4 Eliocroca?    settlement
# 265893           An ancient place, cited: BAtlas 27 A3 Epora    settlement
# 265894     An ancient place, cited: BAtlas 27 F1 Etobesa/...    settlement
# 265896     A Roman villa located at the modern lighthouse...         villa
# 265897     A promontory on the east coast of the Iberian ...          cape
# 265898     An ancient place, cited: BAtlas 27 D4 Ficarien...    settlement
# 265899         An ancient place, cited: BAtlas 27 D3 Fortuna     sanctuary
# 265900       An ancient place, cited: BAtlas 27 B4 Fraxinum?    settlement
# 265901     An ancient place, cited: BAtlas 27 C1 Fuente d...         villa
# 265902     An ancient place, cited: BAtlas 27 B3 Fuente d...         villa
# 265903     An ancient place, cited: BAtlas 27 A4 Fuente d...         villa
# 265905       An ancient place, cited: BAtlas 27 B3 Giribaile    settlement
# 265906       An ancient place, cited: BAtlas 27 inset Guium?    settlement
# 265914     An ancient place, cited: BAtlas 27 B4 Hoyo de ...          mine
# 265916     An ancient place, cited: BAtlas 27 inset Iamo/...    settlement
# 265917        An ancient place, cited: BAtlas 27 E3 (I)Aspis       unknown
# 265919     An ancient place, cited: BAtlas 27 A4 Igabrum/...    settlement
# ...                                                      ...           ...
# 963101396                      An unnamed villa of Cyrenaica         villa
# 963101397                      An unnamed villa of Cyrenaica         villa
# 963101398                      An unnamed villa of Cyrenaica         villa
# 963101399                      An unnamed villa of Cyrenaica         villa
# 963101400                      An unnamed villa of Cyrenaica         villa
# 963101401                      An unnamed villa of Cyrenaica         villa
# 963101402                      An unnamed villa of Cyrenaica         villa
# 963101403                      An unnamed villa of Cyrenaica         villa
# 963101404                      An unnamed villa of Cyrenaica         villa
# 963101405                      An unnamed villa of Cyrenaica         villa
# 963101406                      An unnamed villa of Cyrenaica         villa
# 963101407                      An unnamed villa of Cyrenaica         villa
# 963101408                      An unnamed villa of Cyrenaica         villa
# 963101409                      An unnamed villa of Cyrenaica         villa
# 973204925  A first century BC bath complex in Pompeii bui...          bath
# 732014845             A nuragic complex near Uras, Sardinia.       nuraghe
# 32331671   A nuragic site located near Pozzomaggiore, Sar...       nuraghe
# 32331672                                                 NaN       nuraghe
# 689737510  Lake Matese is a glacial lake located in the M...          lake
# 689737511  Bathampton Down is a limestone plateau near Ba...       plateau
# 689737512  Bindon Hill is the site of extensive Iron Age ...          fort
# 858265770  The Uffington White Horse is stylized prehisto...      monument
# 416269079  White Castle hillfort is an Iron Age fort loca...          fort
# 6525101    The Broch of Mousa is a drystone broch in Scot...          fort
# 721382239  Black Ball Camp or Gallox hill fort is an Iron...          fort
# 721382240  Grabbist hill fort is an Iron Age hill-fort lo...          fort
# 893850615  Worlebury Camp is the site of an Iron Age hill...          fort
# 535296216  A first century A.D. amphitheater at Alba Fuce...  amphitheatre
# 233061794  A small amphitheater measuring ca. 100 x 70 me...  amphitheatre
# 743134062  The Roman sanctuary of Santalla de Bóveda date...      temple-2
#
#            maxDate  minDate               path    reprLat   reprLong  \
# id
# 48210385    1453.0    640.0   /places/48210385  42.082885  13.411984
# 48210386     300.0   -750.0   /places/48210386  42.419374  11.628546
# 265876       640.0   -330.0     /places/265876  39.460299  -3.606772
# 265877       300.0   -330.0     /places/265877  38.988847  -0.515639
# 265878       300.0   -330.0     /places/265878  37.241792  -2.403309
# 265880      2100.0   -750.0     /places/265880  38.842795   0.107511
# 265882       300.0    -30.0     /places/265882  37.463838  -3.924959
# 265883       640.0   -750.0     /places/265883  38.908393   1.432146
# 265884      2100.0   -750.0     /places/265884  38.980000   1.430000
# 265886       300.0    -30.0     /places/265886  38.640276  -3.362253
# 265887       300.0   -550.0     /places/265887  39.624587  -0.594758
# 265888       300.0   -330.0     /places/265888  39.624587  -0.594758
# 265890       300.0   -330.0     /places/265890  38.447444  -2.048390
# 265891       640.0   -330.0     /places/265891  37.671353  -1.698809
# 265893       640.0   -330.0     /places/265893  38.026033  -4.381896
# 265894       300.0   -330.0     /places/265894  40.078768   0.135423
# 265896      2100.0    -30.0     /places/265896  36.726647  -3.957694
# 265897      2100.0    -30.0     /places/265897  38.733590   0.230329
# 265898       300.0    -30.0     /places/265898  37.599034  -1.313677
# 265899       300.0   -330.0     /places/265899  38.208848  -1.143263
# 265900       640.0    -30.0     /places/265900  37.727146  -3.047757
# 265901       640.0    300.0     /places/265901  40.448617  -2.339264
# 265902       640.0    300.0     /places/265902  38.182964  -3.275718
# 265903       640.0    -30.0     /places/265903  37.474391  -4.425933
# 265905       300.0   -330.0     /places/265905  38.122254  -3.483153
# 265906       300.0    -30.0     /places/265906  39.339079   3.050936
# 265914       300.0   -330.0     /places/265914  37.128828  -3.605316
# 265916       640.0   -330.0     /places/265916  40.002343   3.839243
# 265917       640.0    -30.0     /places/265917  38.500000  -0.500000
# 265919      2100.0    -30.0     /places/265919  37.474155  -4.425943
# ...            ...      ...                ...        ...        ...
# 963101396      NaN      NaN  /places/963101396  31.917701  20.087018
# 963101397      NaN      NaN  /places/963101397  31.884864  20.088029
# 963101398      NaN      NaN  /places/963101398  31.873767  20.043114
# 963101399      NaN      NaN  /places/963101399  31.613038  20.108718
# 963101400      NaN      NaN  /places/963101400  31.604107  20.125143
# 963101401      NaN      NaN  /places/963101401  30.566280  20.237901
# 963101402      NaN      NaN  /places/963101402  32.466308  20.976753
# 963101403      NaN      NaN  /places/963101403  32.437376  20.998515
# 963101404      NaN      NaN  /places/963101404  32.419974  20.608117
# 963101405      NaN      NaN  /places/963101405  32.391262  20.619183
# 963101406      NaN      NaN  /places/963101406  32.443884  20.869447
# 963101407      NaN      NaN  /places/963101407  32.458714  20.900927
# 963101408      NaN      NaN  /places/963101408  32.498444  20.713837
# 963101409      NaN      NaN  /places/963101409  32.500302  20.760837
# 973204925   2100.0   -330.0  /places/973204925  40.748676  14.482779
# 732014845  -1000.0  -2000.0  /places/732014845  39.689668   8.710675
# 32331671   -1000.0  -2000.0   /places/32331671  40.394888   8.673330
# 32331672   -1000.0  -2000.0   /places/32331672  40.278618   8.768868
# 689737510   2100.0   1700.0  /places/689737510  41.407954  14.397693
# 689737511   2100.0   1700.0  /places/689737511  51.387596  -2.325122
# 689737512    100.0   -800.0  /places/689737512  50.622170  -2.234610
# 858265770    100.0   -800.0  /places/858265770  51.578208  -1.566610
# 416269079    100.0   -800.0  /places/416269079  55.909477  -2.619778
# 6525101      100.0   -800.0    /places/6525101  59.995330  -1.182102
# 721382239    100.0   -800.0  /places/721382239  51.174327  -3.454245
# 721382240    100.0   -800.0  /places/721382240  51.183180  -3.456454
# 893850615    100.0   -800.0  /places/893850615  51.357425  -2.985153
# 535296216   2100.0    -30.0  /places/535296216  42.077222  13.412317
# 233061794      NaN      NaN  /places/233061794  37.909675  22.892179
# 743134062    640.0    -30.0  /places/743134062  42.980095  -7.685967
#
#                                              timePeriodsKeys timePeriodsRange  \
# id
# 48210385                                 mediaeval-byzantine     640.0,1453.0
# 48210386      archaic,classical,hellenistic-republican,roman     -750.0,300.0
# 265876             hellenistic-republican,roman,late-antique     -330.0,640.0
# 265877                          hellenistic-republican,roman     -330.0,300.0
# 265878                          hellenistic-republican,roman     -330.0,300.0
# 265880     archaic,classical,hellenistic-republican,roman...    -750.0,2100.0
# 265882                                                 roman      -30.0,300.0
# 265883     archaic,classical,hellenistic-republican,roman...     -750.0,640.0
# 265884     archaic,classical,hellenistic-republican,roman...    -750.0,2100.0
# 265886                                                 roman      -30.0,300.0
# 265887                classical,hellenistic-republican,roman     -550.0,300.0
# 265888                          hellenistic-republican,roman     -330.0,300.0
# 265890                          hellenistic-republican,roman     -330.0,300.0
# 265891             hellenistic-republican,roman,late-antique     -330.0,640.0
# 265893             hellenistic-republican,roman,late-antique     -330.0,640.0
# 265894     hellenistic-republican,hellenistic-roman-early...     -330.0,300.0
# 265896                             roman,late-antique,modern     -30.0,2100.0
# 265897                                          roman,modern     -30.0,2100.0
# 265898                                                 roman      -30.0,300.0
# 265899                          hellenistic-republican,roman     -330.0,300.0
# 265900                                    roman,late-antique      -30.0,640.0
# 265901                                          late-antique      300.0,640.0
# 265902                                          late-antique      300.0,640.0
# 265903                                    roman,late-antique      -30.0,640.0
# 265905                          hellenistic-republican,roman     -330.0,300.0
# 265906                                                 roman      -30.0,300.0
# 265914                          hellenistic-republican,roman     -330.0,300.0
# 265916             hellenistic-republican,roman,late-antique     -330.0,640.0
# 265917                                    roman,late-antique      -30.0,640.0
# 265919         roman,late-antique,mediaeval-byzantine,modern     -30.0,2100.0
# ...                                                      ...              ...
# 963101396                                                NaN              NaN
# 963101397                                                NaN              NaN
# 963101398                                                NaN              NaN
# 963101399                                                NaN              NaN
# 963101400                                                NaN              NaN
# 963101401                                                NaN              NaN
# 963101402                                                NaN              NaN
# 963101403                                                NaN              NaN
# 963101404                                                NaN              NaN
# 963101405                                                NaN              NaN
# 963101406                                                NaN              NaN
# 963101407                                                NaN              NaN
# 963101408                                                NaN              NaN
# 963101409                                                NaN              NaN
# 973204925              hellenistic-roman-early-empire,modern    -330.0,2100.0
# 732014845                                  2nd-millenium-bce  -2000.0,-1000.0
# 32331671                                   2nd-millenium-bce  -2000.0,-1000.0
# 32331672                                   2nd-millenium-bce  -2000.0,-1000.0
# 689737510                                             modern    1700.0,2100.0
# 689737511                                             modern    1700.0,2100.0
# 689737512                                   iron-age-britain     -800.0,100.0
# 858265770                                   iron-age-britain     -800.0,100.0
# 416269079                                   iron-age-britain     -800.0,100.0
# 6525101                                     iron-age-britain     -800.0,100.0
# 721382239                                   iron-age-britain     -800.0,100.0
# 721382240                                   iron-age-britain     -800.0,100.0
# 893850615                                   iron-age-britain     -800.0,100.0
# 535296216                                       roman,modern     -30.0,2100.0
# 233061794                                                NaN              NaN
# 743134062                                 roman,late-antique      -30.0,640.0
#
#                                       title
# id
# 48210385                    Borgo Medievale
# 48210386             Tempio Grande at Vulci
# 265876                  Consabura/Consabrum
# 265877                          Contestania
# 265878                   Cueva de la Paloma
# 265880               Dianium/Hemeroskopeion
# 265882                                Ebura
# 265883                               Ebusus
# 265884                      Ebusus (island)
# 265886                                Edeba
# 265887                         Edeta/Leiria
# 265888                             Edetania
# 265890                   Elche de la Sierra
# 265891                           Eliocroca?
# 265893                                Epora
# 265894                    Etobesa/Etouissa?
# 265896      Roman Villa at El Faro (Torrox)
# 265897     Ferrarium/Tenebrium (promontory)
# 265898                   Ficariensis Locus?
# 265899                              Fortuna
# 265900                            Fraxinum?
# 265901                      Fuente de Baños
# 265902                 Fuente de la Pañuela
# 265903                Fuente de las Piedras
# 265905                            Giribaile
# 265906                               Guium?
# 265914                   Hoyo de la Campana
# 265916                           Iamo/Iamna
# 265917                             (I)Aspis
# 265919                      Igabrum/Egabrum
# ...                                     ...
# 963101396                     Unnamed villa
# 963101397                     Unnamed villa
# 963101398                     Unnamed villa
# 963101399                     Unnamed villa
# 963101400                     Unnamed villa
# 963101401                     Unnamed villa
# 963101402                     Unnamed villa
# 963101403                     Unnamed villa
# 963101404                     Unnamed villa
# 963101405                     Unnamed villa
# 963101406                     Unnamed villa
# 963101407                     Unnamed villa
# 963101408                     Unnamed villa
# 963101409                     Unnamed villa
# 973204925                    Suburban Baths
# 732014845               Nuraghe Domu Beccia
# 32331671                     Nuraghe Ruggiu
# 32331672         Nuraghe Ruggiu at Filigosa
# 689737510                       Lake Matese
# 689737511                   Bathampton Down
# 689737512                       Bindon Hill
# 858265770             Uffington White Horse
# 416269079             White Castle hillfort
# 6525101                      Broch of Mousa
# 721382239                   Black Ball Camp
# 721382240                Grabbist hill-fort
# 893850615                    Worlebury Camp
# 535296216       Amphitheater of Alba Fucens
# 233061794     Roman amphitheater at Corinth
# 743134062                Santalla de Bóveda
#
# [36467 rows x 11 columns]

# %% [markdown]
# Consider the 'id' Column. This number is a unique identifier for every row in our Table.
# We can access a row through this id:

# %%
datatable.loc[48210386]
# Out:
# authors                                        Becker, J., T. Elliott
# description         A major urban sanctuary at Vulci with a long p...
# featureTypes                                                 temple-2
# maxDate                                                           300
# minDate                                                          -750
# path                                                 /places/48210386
# reprLat                                                       42.4194
# reprLong                                                      11.6285
# timePeriodsKeys        archaic,classical,hellenistic-republican,roman
# timePeriodsRange                                         -750.0,300.0
# title                                          Tempio Grande at Vulci
# Name: 48210386, dtype: object

# %%
datatable.loc[48210386]['reprLat']
# Out:
# 42.4193742

# %% [markdown]
# The big problem here: We do it the other way around. We are scanning the Corpus for the titles of places!
# At the same time we need to be aware that there might be different words indicating the same place (Athens, Athenae ..).
# The idea is to create a huge python-dictionary that maps words representing places to the corresponding id of our datatable.

# %%
word_lookup = load_dict_from_file("./data/word_lookup.txt")

# %%
word_lookup_extension = load_dict_from_file("./data/word_lookup_extension.txt")
word_lookup = {**word_lookup, **word_lookup_extension}
filteredWords = pd.read_csv('./data/FilteredWords.txt', header=None, delimiter="\t",)
for word in filteredWords.values[0].tolist():
    if word in word_lookup.keys():
        del word_lookup[word]

# %%
for word, the_id in word_lookup.items():
    if the_id == 491528:
        print(word, the_id)
# Out:
# arrolos 491528
# arolos 491528
# arauros 491528
# arason 491528

# %% [markdown]
# Now let's load and scan our Herodotus Corpus!

# %%
herodotus_tmp=open('./data/herodotus_history.txt','r',newline='\n').read()
herodotus_tmp = herodotus_tmp.replace('\n', ' ')
herodotus_tmp = re.sub(pattern='\W', string=herodotus_tmp, repl=" ")
herodotus_tmp = re.sub(pattern=' +', string=herodotus_tmp, repl=" ").lower()
herodotus_tmp = herodotus_tmp.split()

# %%
words_in_Herodotus = np.asarray(herodotus_tmp)

# %%
words_in_Herodotus.size
# Out:
# 188799

# %%
def analyse_Text(topic_lists=[[]], topic_name_list=["Count"],scope=15):
    if len(topic_lists)!=len(topic_name_list):
        raise Exception('Number of topic lists needs to be equal to number of topic names!')

    text_analysis = {}
    
    
    for topic_index, topic_words in enumerate(topic_lists, start=0):
        topic_name = topic_name_list[topic_index]
    
        for index, place_name in enumerate(words_in_Herodotus, start=0):
            if place_name in word_lookup.keys():
                if len(topic_words) == 0:
                #Simple Count Analysis:
                    if place_name not in text_analysis.keys():
                        #initialize place entry for all topics:
                        text_analysis[place_name]={}
                        for t in topic_name_list:
                            print(topic_name)
                            text_analysis[place_name][topic_name]= [0,[]]
                    text_analysis[place_name][topic_name][0]+=1
                    text_analysis[place_name][topic_name][1].append(index//1000)
                        
                else:
                #Topic specific Analysis:
                    for i in range(max(index-scope,0),
                                   min(index+scope+1, len(words_in_Herodotus))):
                        if words_in_Herodotus[i] in topic_words: 
                            if place_name not in text_analysis.keys():
                                #initialize place entry for all topics:
                                text_analysis[place_name]={}
                                for t in topic_name_list:
                                    text_analysis[place_name][t]= [0,[]]
                            text_analysis[place_name][topic_name][0]+=1
                            text_analysis[place_name][topic_name][1].append(index//1000)
    return text_analysis

# %%
place_analysis = analyse_Text([["battle", "war", "weapon"],["battle", "war", "weapon"]], ["Count", "War"])
place_analysis
# Out:
# {'colchis': {'Count': [1, [0]], 'War': [1, [0]]},
#  'phasis': {'Count': [1, [0]], 'War': [1, [0]]},
#  'priene': {'Count': [1, [2]], 'War': [1, [2]]},
#  'miletus': {'Count': [3, [2, 156, 160]], 'War': [3, [2, 156, 160]]},
#  'cimmerians': {'Count': [2, [2, 2]], 'War': [2, [2, 2]]},
#  'alyattes': {'Count': [4, [2, 2, 3, 13]], 'War': [4, [2, 2, 3, 13]]},
#  'lydia': {'Count': [2, [2, 4]], 'War': [2, [2, 4]]},
#  'erythrae': {'Count': [2, [2, 2]], 'War': [2, [2, 2]]},
#  'eleusis': {'Count': [1, [4]], 'War': [1, [4]]},
#  'sardis': {'Count': [6, [7, 12, 14, 150, 150, 159]],
#   'War': [6, [7, 12, 14, 150, 150, 159]]},
#  'athens': {'Count': [5, [11, 151, 181, 184, 185]],
#   'War': [5, [11, 151, 181, 184, 185]]},
#  'tegea': {'Count': [1, [11]], 'War': [1, [11]]},
#  'delphi': {'Count': [2, [11, 164]], 'War': [2, [11, 164]]},
#  'pteria': {'Count': [1, [14]], 'War': [1, [14]]},
#  'phocaea': {'Count': [1, [15]], 'War': [1, [15]]},
#  'thyrea': {'Count': [1, [15]], 'War': [1, [15]]},
#  'nineveh': {'Count': [1, [20]], 'War': [1, [20]]},
#  'babylon': {'Count': [3, [29, 36, 105]], 'War': [3, [29, 36, 105]]},
#  'ionia': {'Count': [3, [31, 143, 159]], 'War': [3, [31, 143, 159]]},
#  'assyria': {'Count': [1, [34]], 'War': [1, [34]]},
#  'syria': {'Count': [1, [72]], 'War': [1, [72]]},
#  'sidon': {'Count': [1, [72]], 'War': [1, [72]]},
#  'thebes': {'Count': [1, [73]], 'War': [1, [73]]},
#  'corinth': {'Count': [1, [73]], 'War': [1, [73]]},
#  'lycia': {'Count': [1, [76]], 'War': [1, [76]]},
#  'samos': {'Count': [5, [84, 85, 88, 103, 162]],
#   'War': [5, [84, 85, 88, 103, 162]]},
#  'lance': {'Count': [1, [92]], 'War': [1, [92]]},
#  'nysa': {'Count': [1, [95]], 'War': [1, [95]]},
#  'scythia': {'Count': [3, [102, 102, 124]], 'War': [3, [102, 102, 124]]},
#  'euxine': {'Count': [1, [113]], 'War': [1, [113]]},
#  'thermodon': {'Count': [1, [123]], 'War': [1, [123]]},
#  'sauromatae': {'Count': [1, [124]], 'War': [1, [124]]},
#  'maeotis': {'Count': [1, [127]], 'War': [1, [127]]},
#  'libya': {'Count': [1, [132]], 'War': [1, [132]]},
#  'psylli': {'Count': [1, [133]], 'War': [1, [133]]},
#  'strymon': {'Count': [1, [138]], 'War': [1, [138]]},
#  'crotona': {'Count': [1, [145]], 'War': [1, [145]]},
#  'sybaris': {'Count': [1, [145]], 'War': [1, [145]]},
#  'sicily': {'Count': [1, [145]], 'War': [1, [145]]},
#  'sicyon': {'Count': [2, [149, 149]], 'War': [2, [149, 149]]},
#  'argos': {'Count': [1, [149]], 'War': [1, [149]]},
#  'attica': {'Count': [3, [151, 152, 179]], 'War': [3, [151, 152, 179]]},
#  'ephesus': {'Count': [1, [157]], 'War': [1, [157]]},
#  'salamis': {'Count': [1, [158]], 'War': [1, [158]]},
#  'maeander': {'Count': [1, [159]], 'War': [1, [159]]},
#  'aeolis': {'Count': [1, [159]], 'War': [1, [159]]},
#  'cyme': {'Count': [1, [159]], 'War': [1, [159]]},
#  'chios': {'Count': [1, [160]], 'War': [1, [160]]},
#  'lade': {'Count': [1, [160]], 'War': [1, [160]]},
#  'atarneus': {'Count': [1, [164]], 'War': [1, [164]]},
#  'lampsacus': {'Count': [1, [165]], 'War': [1, [165]]},
#  'tiryns': {'Count': [1, [172]], 'War': [1, [172]]},
#  'hercules': {'Count': [1, [177]], 'War': [1, [177]]},
#  'marathon': {'Count': [3, [178, 178, 183]], 'War': [3, [178, 178, 183]]},
#  'sparta': {'Count': [1, [179]], 'War': [1, [179]]},
#  'paros': {'Count': [1, [181]], 'War': [1, [181]]},
#  'lemnos': {'Count': [1, [183]], 'War': [1, [183]]},
#  'macedonia': {'Count': [1, [185]], 'War': [1, [185]]},
#  'abide': {'Count': [1, [186]], 'War': [1, [186]]}}

# %%
place_analysis.keys()
# Out:
# dict_keys(['colchis', 'phasis', 'priene', 'miletus', 'cimmerians', 'alyattes', 'lydia', 'erythrae', 'eleusis', 'sardis', 'athens', 'tegea', 'delphi', 'pteria', 'phocaea', 'thyrea', 'nineveh', 'babylon', 'ionia', 'assyria', 'syria', 'sidon', 'thebes', 'corinth', 'lycia', 'samos', 'lance', 'nysa', 'scythia', 'euxine', 'thermodon', 'sauromatae', 'maeotis', 'libya', 'psylli', 'strymon', 'crotona', 'sybaris', 'sicily', 'sicyon', 'argos', 'attica', 'ephesus', 'salamis', 'maeander', 'aeolis', 'cyme', 'chios', 'lade', 'atarneus', 'lampsacus', 'tiryns', 'hercules', 'marathon', 'sparta', 'paros', 'lemnos', 'macedonia', 'abide'])

# %%
len(words_in_Herodotus)
# Out:
# 188799

# %%
def analysis2Json(singe_place_analysis):
    result = {
                "count": singe_place_analysis[0],
                "occurrences": singe_place_analysis[1]
               }
    return result

# %%
def feature2Json( title,  description,  Lat,  Lng,  singe_place_analysis, featureTypes, timePeriodsKeys, timePeriodsRange, minDate, maxDate):
    result = {
         "type": "Feature",
         "properties": {
             "title": title,
             "description": description,
             "featureTypes": featureTypes,
             "timePeriodsKeys": timePeriodsKeys,
             "timePeriodsRange": timePeriodsRange,
             "minDate": minDate,
             "maxDate": maxDate,
             "Analysis": singe_place_analysis,
         },
        "geometry": {
             "type": "Point",
             "coordinates": [
                 Lng,
                 Lat
             ]  
         }
        }
    return result

# %%
def write_Feature_Collection(filepath, place_analysis, collection_name):
    features = []
    for word, count in place_analysis.items():
        features.append(
            feature2Json(
                datatable.loc[word_lookup[word]]['title'],
                datatable.loc[word_lookup[word]]['description'],
                datatable.loc[word_lookup[word]]['reprLat'], 
                datatable.loc[word_lookup[word]]['reprLong'],
                place_analysis[word],
                datatable.loc[word_lookup[word]]['featureTypes'],
                datatable.loc[word_lookup[word]]['timePeriodsKeys'],
                datatable.loc[word_lookup[word]]['timePeriodsRange'],
                datatable.loc[word_lookup[word]]['minDate'],
                datatable.loc[word_lookup[word]]['maxDate']
            )
        )
    FeatureCollection = {
        "type": "FeatureCollection",
        "features": features
     }

    f = open(filepath, 'w')  # start to write JS-variable
    f.write("var " + collection_name + " = \n")
    f.flush
    f.close()

    with open(filepath, 'a') as f:  # append JSON object
        json.dump(FeatureCollection, f, indent=1)

# %%
#place_analysis = analyse_Text([[]])
#write_Feature_Collection( filepath = './count.js', 
#                         place_analysis = place_analysis, 
#                         collection_name = "count")

place_analysis = analyse_Text([["war", "weapon", "battle"]], ["War"])
write_Feature_Collection( filepath = './war.js', 
                         place_analysis = place_analysis, 
                         collection_name = "War_Topic")

place_analysis = analyse_Text([["croesus"]], ["Count"] )
write_Feature_Collection( filepath = './croesus.js', 
                         place_analysis = place_analysis, 
                         collection_name = "Croesus")

place_analysis = analyse_Text([["temple", "god", "goddess", "sacrifice"]], ["Religion"] )
write_Feature_Collection( filepath = './religion.js', 
                         place_analysis = place_analysis, 
                         collection_name = "Religion_Topic")

place_analysis = analyse_Text([["war", "weapon", "battle"],
                               ["temple", "god", "goddess", "sacrifice"]
                              ], 
                              ["War", "Religion"] )
write_Feature_Collection( filepath = './war_religion.js', 
                         place_analysis = place_analysis, 
                         collection_name = "War_Religion_Topic")

# %%
i=0
for word, count in place_analysis.items():
    if i<30:
        print(place_analysis[word][0])
    i+=1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-217-13a05d0cf750> in <module>()
#       1 i=0
# ----> 2 for word, count in place_analysis.items():
#       3     if i<30:
#       4         print(place_analysis[word][0])
#       5     i+=1
#
# AttributeError: 'list' object has no attribute 'items'

# %%
len([[]])
# Out:
# 1

# %%
len[[]][0]
# Out:
# []

# %%
place_analysis
# Out:
# {}

# %%
if 'consabura'
# Out:
# {'consabura': 265876,
#  'consabrum': 265876,
#  'kondabora': 265876,
#  'consaburrenses': 265876,
#  'contestania': 265877,
#  'contestani': 265877,
#  'hemeroskopeion': 265880,
#  'dénia': 265880,
#  'ebura': 265882,
#  'cerialis': 265882,
#  'edeba': 265886,
#  'edeta': 265887,
#  'leiria': 265887,
#  'eliocroca': 265891,
#  'epora': 265893,
#  'epora foederatorum': 265893,
#  'etouissa': 265894,
#  'villa del faro': 265896,
#  'ferrarium': 265897,
#  'tenebrium': 265897,
#  'ficariensis locus': 265898,
#  'fortuna': 265899,
#  'guium': 265906,
#  'cinium': 265906,
#  'iamo': 265916,
#  'iamna': 265916,
#  'iaspis': 265917,
#  'igabrum': 265919,
#  'egabrum': 265919,
#  'municipium iulium': 265919,
#  'cabra': 265919,
#  'ildum': 265920,
#  'iliberri': 265921,
#  'elvira': 265921,
#  'municipium florentinum': 265921,
#  'granada': 265921,
#  'ilsh': 265922,
#  'ilici': 265922,
#  'ecclesia elotana': 265922,
#  'elche': 265922,
#  'ilicitanus sinus': 265923,
#  'iliturgi': 265924,
#  'iliturgicola': 265925,
#  'illikitanos limen': 265926,
#  'ilorci': 265927,
#  'ilourgeia': 265927,
#  'ilounon': 265928,
#  'ilugo': 265929,
#  'ilurco': 265930,
#  'ipolcobulcola': 265935,
#  'municipium polconensium': 265935,
#  'iponuba': 265936,
#  'hippo nova': 265936,
#  'ipsca': 265937,
#  'municipium contributum ipscense': 265937,
#  'ituci': 265938,
#  'col. virtus iulia': 265938,
#  'isturgi': 265939,
#  'municipium triumphale': 265939,
#  'laminium': 265946,
#  'libisosa': 265949,
#  'colonia forum augustum': 265949,
#  'lobetanoi': 265951,
#  'longuntica': 265952,
#  'lucentum': 265954,
#  'akra leuke': 265954,
#  'castrum album': 265954,
#  'menova': 265959,
#  'maenoba': 265959,
#  'mago': 265960,
#  'marianus m.': 265966,
#  'mentesa': 265969,
#  'mentesa bastia': 265970,
#  'morana': 265975,
#  'murgi': 265977,
#  'obulco': 265982,
#  'municipium pontificense': 265982,
#  'porcuna': 265982,
#  'ocules': 265983,
#  'vcles': 265983,
#  'uclés': 265983,
#  'olcades': 265984,
#  'onuba': 265985,
#  'opta': 265987,
#  'oretana iuga': 265988,
#  'oretania': 265989,
#  'oretani': 265989,
#  'oretanoi': 265989,
#  'oretum': 265990,
#  'oria': 265990,
#  'horetum': 265990,
#  'orospeda m.': 265992,
#  'ossigi': 265994,
#  'municipium latonium': 265994,
#  'palma': 265998,
#  'parietinae': 265999,
#  'pityussae': 266001,
#  'planesia': 266002,
#  'portos magnos': 266005,
#  'portus sucronis': 266006,
#  'sacili': 266017,
#  'municipium martiale': 266017,
#  'saguntum': 266021,
#  'arse': 266021,
#  'col. salariensis': 266022,
#  'vbeda': 266022,
#  'úbeda': 266022,
#  'salika': 266023,
#  'saltigi': 266025,
#  'sanisera': 266026,
#  'saturni': 266030,
#  'scombraria pr.': 266030,
#  'scombraria': 266032,
#  'hercules': 266032,
#  'sebelaci': 266034,
#  'segisa': 266035,
#  'segobriga': 266036,
#  'sexi': 266038,
#  'saxetanum': 266038,
#  'firmum iulium': 266038,
#  'almuñécar': 266038,
#  'sisapo': 266043,
#  'saesapo': 266043,
#  'sisalo': 266043,
#  'solorius m.': 266046,
#  'sorobis': 266047,
#  'sosontigi': 266048,
#  'sosintigi': 266048,
#  'alcabdet': 266048,
#  'alcaudete': 266048,
#  'spartarius campus': 266050,
#  'sucia': 266051,
#  'sitia': 266051,
#  'stia': 266051,
#  'sutia': 266051,
#  'sucronensis sinus': 266054,
#  'suel': 266055,
#  'tader': 266057,
#  'tagili': 266058,
#  'respublica tagilitana': 266058,
#  'tagonios': 266059,
#  'thiar': 266063,
#  'toletum': 266066,
#  'toledo': 266066,
#  'col. augusta gemella': 266070,
#  'itukke': 266070,
#  'martos': 266070,
#  'tuci': 266071,
#  'tugia': 266072,
#  'tugiensis saltus': 266073,
#  'turaniana': 266074,
#  'turdetania': 266075,
#  'turdetani': 266075,
#  'turia': 266076,
#  'tutugi': 266078,
#  'col. claritas iulia': 266081,
#  'udiva': 266082,
#  'uduba': 266082,
#  'urci': 266085,
#  'urcitanus sinus': 266086,
#  'urgao': 266087,
#  'vircao': 266087,
#  'municipium albense urgauonense': 266087,
#  'ariona': 266087,
#  'arjona': 266087,
#  'vergilia': 266093,
#  'vicus cuminarius': 266094,
#  'vivatia': 266099,
#  'viatia': 266099,
#  'biatia': 266099,
#  'adiungi': 270292,
#  'aimiliana': 270293,
#  'alternum': 270294,
#  'alterum': 270294,
#  'asterum': 270294,
#  'althaia': 270296,
#  'cartala': 270296,
#  'amtorgis': 270297,
#  'barnakis': 270301,
#  'bergoula': 270304,
#  'bernaba': 270305,
#  'bigerra': 270306,
#  'begerra': 270306,
#  'celeret': 270310,
#  'celeri': 270310,
#  'cusubi': 270311,
#  'casuli': 270311,
#  'egelesta 1': 270313,
#  'egelesta 2': 270314,
#  'hannibalis': 270316,
#  'helonis': 270317,
#  'hyops': 270318,
#  'ibe': 270320,
#  'icositani': 270321,
#  'ileosca': 270324,
#  'ispinon': 270326,
#  'istonion': 270327,
#  'karka': 270330,
#  'kerouaria': 270331,
#  'krabrasia': 270332,
#  'laccuris': 270334,
#  'lersensis res publicae': 270335,
#  'laxta': 270337,
#  'libana': 270339,
#  'lobeton': 270340,
#  'aluarrazin': 270340,
#  'albarracin': 270340,
#  'loupparia': 270341,
#  'lyco': 270342,
#  'martium ucia': 270344,
#  'mastia': 270345,
#  'massia': 270345,
#  'menariae': 270348,
#  'molybdina': 270350,
#  'nobila': 270352,
#  'oinoussa': 270355,
#  'varciliens(...)': 270357,
#  'ourkesa': 270358,
#  'paterniana': 270361,
#  'plumbaria': 270362,
#  'poukialia': 270363,
#  'ripa': 270365,
#  's. martini, mon.': 270367,
#  'saitabikoula': 270368,
#  'salaria bastetana': 270369,
#  'soricaria': 270373,
#  'sucaelo': 270374,
#  'siccaenum': 270374,
#  'tiquadra': 270376,
#  'tourboula': 270377,
#  'ulissi': 270380,
#  'ulisi': 270380,
#  'odyssea': 270380,
#  'urbiaca': 270381,
#  'valebonga': 270384,
#  'alebus': 271047,
#  'berybraces': 271049,
#  'crabrasiae iugum': 271050,
#  'gymnetes': 271051,
#  'herna': 271052,
#  'hiberi': 271053,
#  'hystra civitas': 271055,
#  'malacha': 271058,
#  'malachae': 271059,
#  'massiena urbs': 271060,
#  'menace': 271062,
#  'minervae': 271063,
#  'naccararum palus': 271064,
#  'namnatius portus': 271065,
#  'noctilucae': 271066,
#  'phoenices': 271067,
#  '[pityussa] iugum': 271068,
#  'cautes': 271068,
#  'sardum mare': 271069,
#  'sicana civitas': 271071,
#  'silurus m.': 271073,
#  'theodorus': 271075,
#  'trete iugum': 271076,
#  'tyrius': 271078,
#  'veneris fanum': 271079,
#  'veneris litus': 271081,
#  'abila m.': 275577,
#  'monte hacho': 275577,
#  'abilyx': 275577,
#  'ad mercuri': 275579,
#  'aquae dacicae': 275590,
#  'aquila maior pr.': 275591,
#  'aquila minor pr.': 275592,
#  'autololes': 275596,
#  'autoteles': 275596,
#  'banasa': 275599,
#  'col. iulia valentia banasa': 275599,
#  'baniurae': 275600,
#  'banioubai': 275600,
#  'boniuricis': 275600,
#  'baquates': 275601,
#  'bakouatai': 275601,
#  'ouakouatai': 275601,
#  'barbari pr.': 275602,
#  'cephisis l.': 275613,
#  'columnae herculis': 275614,
#  'cottae': 275615,
#  'kotes': 275615,
#  'gytte': 275615,
#  'ermaia akra': 275624,
#  'frigidae': 275629,
#  'friglas': 275629,
#  'kaunoi': 275650,
#  'iangaukanoi': 275650,
#  'laud': 275665,
#  'lixitai': 275666,
#  'aulucus': 275666,
#  'lixox': 275667,
#  'lunx': 275667,
#  'macenites': 275670,
#  'makanitai': 275670,
#  'masikes': 275672,
#  'maurusii': 275674,
#  'mauri': 275674,
#  'maurensioi': 275674,
#  'metagonitai': 275679,
#  'ouerbikai': 275688,
#  'oueroueis': 275689,
#  'rabat': 275696,
#  'salat': 275697,
#  'salenses': 275698,
#  'salinsai': 275698,
#  'septem': 275703,
#  'septa': 275703,
#  'ceuta': 275703,
#  'septem fratres m.': 275704,
#  'sokossioi': 275723,
#  'ampelusia pr.': 275724,
#  'sububus': 275727,
#  'sububa': 275727,
#  'taenia longa': 275730,
#  'tamucus': 275732,
#  'tumuada': 275733,
#  'thamusida': 275734,
#  'tingi': 275736,
#  'tingitani': 275736,
#  'thymiaterion': 275736,
#  'tocolosida': 275737,
#  'tremuli': 275738,
#  'volubilis': 275740,
#  'volubilitani': 275740,
#  'ouoloubilianoi': 275740,
#  'zegrenses': 275742,
#  'zilia': 275743,
#  'zilis': 275744,
#  'col. iulia constantia zilil': 275744,
#  'ad mercurios': 278597,
#  'anides': 278599,
#  'arambys': 278600,
#  'babba': 278602,
#  'col. iulia campestris babba': 278602,
#  'castrabariensis': 278602,
#  'cobucla': 278605,
#  'dugas': 278607,
#  'emporikos kolpos': 278609,
#  'sagigi sinus': 278609,
#  'gilda': 278611,
#  'silda': 278611,
#  'gontiana': 278612,
#  'gentiano': 278612,
#  'hesperioi': 278615,
#  'karikon teichos': 278617,
#  'masaesyli': 278621,
#  'mauritania egel': 278622,
#  'mauritania perosis': 278623,
#  'mauritania salinarum': 278623,
#  'melitta': 278624,
#  'mulelacha pr.': 278625,
#  'nektiberes': 278627,
#  'ouobrix': 278629,
#  'pacatiana': 278631,
#  'pontion': 278632,
#  'pisciana': 278633,
#  'pyron pedion': 278634,
#  'ad fratres': 285393,
#  'ala miliaria': 285411,
#  'tigit': 285411,
#  'albulae': 285412,
#  'praesidium sufative': 285412,
#  'altava': 285413,
#  'aquae sirenses': 285415,
#  'ballene praesidium': 285418,
#  'bavares': 285419,
#  'camarata': 285422,
#  'canarii': 285423,
#  'castra nova': 285424,
#  'castra puerorum': 285425,
#  'castra puerum': 285425,
#  'cen..': 285426,
#  'cen': 285426,
#  'cohors breucorum': 285428,
#  'kaputurbe': 285428,
#  'columnata': 285430,
#  'dryitai': 285437,
#  'eloulioi': 285439,
#  'error': 285440,
#  'gadaum castra': 285444,
#  'herpeditanoi': 285450,
#  'isaris': 285453,
#  'kaputtasaccora': 285456,
#  'kh., see kherba': 285459,
#  'laturus sinus': 285475,
#  'lemnis': 285476,
#  'lucu': 285477,
#  'massaesylii': 285480,
#  'melanogaitouloi': 285484,
#  'mulucha': 285491,
#  'nakmousioi': 285493,
#  'nigritae': 285494,
#  'numerus syrorum': 285495,
#  'pomaria': 285501,
#  'portus divinus': 285502,
#  'portus sigensis': 285504,
#  'regiae': 285509,
#  'rusaddir pr.': 285511,
#  'rusaddi pr.': 285511,
#  'rusaddir': 285512,
#  'sira': 285523,
#  'taladousioi': 285528,
#  'tauria': 285531,
#  'tect(...)': 285533,
#  'tepidae': 285535,
#  'safar': 285535,
#  'tolotai': 285538,
#  'tres': 285540,
#  'ad crispas': 289922,
#  'agilaam': 289924,
#  'artisiga': 289925,
#  'artisica': 289925,
#  'galama': 289927,
#  'cannarum pr.': 289928,
#  'cannar pr.': 289928,
#  'castra severiana': 289929,
#  'chalkorycheia': 289930,
#  'dourdon m.': 289931,
#  'herpis': 289937,
#  'limes muticitanus': 289939,
#  'molochath': 289941,
#  'nigrensis': 289943,
#  'parietina': 289945,
#  'portus caecili': 289947,
#  'sardabale': 289949,
#  'saltus cu(...)': 289950,
#  'silva': 289951,
#  'gilva col.': 289951,
#  'sita col.': 289952,
#  'valonice': 289954,
#  'amata': 29461,
#  'anauon': 29463,
#  'arubu': 29475,
#  'arimaspai': 29482,
#  'ariaspai': 29482,
#  'euergitae': 29482,
#  'māt-aššur': 29492,
#  'subartu': 29492,
#  'subaru': 29492,
#  'šubartum': 29492,
#  'bam': 29501,
#  'barna': 29503,
#  'carmania': 29517,
#  'ancorarius m.': 295215,
#  'zalakon m.': 295215,
#  'arsennaria': 295219,
#  'artennites': 295220,
#  'auzia': 295221,
#  'sauos': 295222,
#  'aucus': 295222,
#  'bantouraroi': 295225,
#  'bida': 295228,
#  'caput cilani': 295239,
#  'cartenna': 295240,
#  'cartennas': 295241,
#  'cartili': 295242,
#  'casae calventi': 295243,
#  'castellum elephantaria': 295244,
#  'castellum tingitanum': 295245,
#  'castellum tulei': 295246,
#  'castra germanorum': 295247,
#  'centenarium': 295249,
#  'chatracharta': 29525,
#  'chinalaph': 295251,
#  'chulimath': 295252,
#  'cissi': 295253,
#  'feratenses': 295261,
#  'ferratus m.': 295262,
#  'feratus m.': 295262,
#  'gunugu': 295268,
#  'iar castellum': 295273,
#  'icampenses': 295274,
#  'icosium': 295276,
#  'al-jazā’ir': 295276,
#  'iesalenses': 295277,
#  'iol caesarea': 295279,
#  'iomnium': 295280,
#  'iubaleni': 295284,
#  'lambdia': 295299,
#  'machousioi': 295301,
#  'macurebi': 295302,
#  'maccui': 295302,
#  'malliana': 295304,
#  'mazices': 295306,
#  'monumentum regiae gentis': 295310,
#  'musones': 295311,
#  'mykenoi': 295311,
#  'nababes': 295313,
#  'nabar': 295314,
#  'obori': 295318,
#  'pastorianensis m.': 295323,
#  'quinquegentiani': 295326,
#  'quiza cenitana': 295327,
#  'rapidum': 295329,
#  'rusguniae': 295331,
#  'tamentfoust': 295331,
#  'rusippisir': 295332,
#  'rusubbicari matidiae': 295333,
#  'rusuccuru': 295334,
#  'rusuccenses': 295334,
#  'serbes': 295338,
#  'sufasar': 295346,
#  'tabianenses': 295348,
#  'thanaramusa castra': 295354,
#  'thudedenses': 295356,
#  'tigava castra': 295357,
#  'tigava municipium': 295358,
#  'tigisi': 295359,
#  'timici': 295362,
#  'toulensioi': 295365,
#  'transcellensis m.': 295366,
#  'vagal': 295369,
#  'zucchabar': 295374,
#  'zouchábbari': 295374,
#  'zraka': 29540,
#  'drangai': 29540,
#  'zarin': 29540,
#  'darabgird': 29542,
#  'drangiane': 29547,
#  'zarangiane': 29547,
#  'drangae': 29547,
#  'derangae': 29547,
#  'drangiani': 29547,
#  'sarangai': 29547,
#  'zarangae': 29547,
#  'epimaranitae': 29556,
#  'nareitai': 29556,
#  'anareitai': 29556,
#  'garm-kerman': 29569,
#  'gedrosia': 29573,
#  'kedrosia': 29573,
#  'gadrosia': 29573,
#  'harmozeia': 29586,
#  'armuzia': 29586,
#  'harmozon': 29586,
#  'ichthyophagoi': 29605,
#  'isatichai': 29610,
#  'kalaiou nesoi': 29620,
#  'kalon oros': 29621,
#  'karkuya': 29625,
#  'korok': 29625,
#  'carcoe': 29625,
#  'karmana': 29626,
#  'korodamon akron': 29633,
#  'macoraba': 29652,
#  'mekka': 29652,
#  'ṃakka': 29652,
#  'makka': 29652,
#  'maka': 29656,
#  'nabataea': 29677,
#  'niriz': 29686,
#  'narezzash': 29686,
#  'oarakta': 29691,
#  'persicus sinus': 29713,
#  'erythraeum mare': 29713,
#  'erythrum mare': 29713,
#  'tamtu shaplitu': 29713,
#  'persian gulf': 29713,
#  'phrada': 29718,
#  'phra': 29718,
#  'prophthasía': 29718,
#  'frakh-kar-peroz': 29718,
#  'propasta': 29718,
#  'farah': 29718,
#  'frāh': 29718,
#  'farāh': 29718,
#  'prophthasia': 29718,
#  'sarapias': 29743,
#  'sarapis': 29743,
#  'sard-kerman': 29744,
#  'ram-shahrestan': 29755,
#  'shiragan': 29756,
#  'sirjan': 29756,
#  'siraf': 29762,
#  'sohar': 29766,
#  'pasa': 29781,
#  'bashiyan': 29781,
#  'fasān': 29781,
#  'fasā': 29781,
#  'tall-e siyāh': 29781,
#  'fassā': 29781,
#  'valashgerd': 29799,
#  'gulashkird': 29799,
#  'bardasir': 29802,
#  'govasir': 29802,
#  'bih-ardashir': 29802,
#  'bardašīr': 29802,
#  'kermān': 29802,
#  'kirman': 29802,
#  'bardasīr': 29802,
#  'gwāšīr': 29802,
#  'govāšīr': 29802,
#  'vēh-artašer': 29802,
#  'vēh-artaḫšēr': 29802,
#  'gavāšīr': 29802,
#  'kirmān': 29802,
#  'yazd': 29811,
#  'issatis': 29811,
#  'zagrus m.': 29816,
#  'addume': 298982,
#  'avastomates': 298985,
#  'baiurae': 298987,
#  'baniures': 298988,
#  'barzufulitani': 298989,
#  'castellum thudedensium': 298991,
#  'cafaves': 298992,
#  'cantauriani': 298993,
#  'chalka': 298994,
#  'fluminenses': 298996,
#  'gaionatis fundus': 298998,
#  'gnouton': 298999,
#  'iar kome': 299001,
#  'isaflenses': 299002,
#  'kanoukis': 299004,
#  'karepoula': 299005,
#  'limes caputcellensis': 299007,
#  'mazucanus fundus': 299009,
#  'modounga': 299010,
#  'repetiniana': 299012,
#  'salutaris silonensis pagus': 299014,
#  'tamariceto praesidium': 299016,
#  'tirinadi': 299017,
#  'usar': 299019,
#  'velisci': 299021,
#  'zabenses': 299023,
#  'achindana': 30203,
#  'agris': 30204,
#  'alexandria in carmania': 30205,
#  'anamis': 30206,
#  'andanis': 30206,
#  'ananis': 30206,
#  'aradarum': 30207,
#  'hardea': 30207,
#  'arai': 30208,
#  'archedotis': 30209,
#  'arciotis': 30209,
#  'artakauna': 30211,
#  'bacinora': 30213,
#  'badara': 30214,
#  'balara': 30214,
#  'badgis': 30215,
#  'bageia pr.': 30217,
#  'bagradas': 30218,
#  'caumatis': 30221,
#  'kanate': 30221,
#  'kanthatis': 30221,
#  'cetrora': 30222,
#  'charadrai': 30223,
#  'chelonophagoi': 30224,
#  'dagaseira': 30226,
#  'daras': 30227,
#  'dendrobosa': 30228,
#  'derane billa': 30229,
#  'derenobilla': 30229,
#  'guzeran-ardashir': 30231,
#  'kujaran': 30231,
#  'hictanis': 30234,
#  'hyktanis': 30234,
#  'kanasida': 30236,
#  'karpella pr.': 30239,
#  'kathraps': 30240,
#  'khwash': 30241,
#  'qash': 30241,
#  'kophas': 30242,
#  'kyiza': 30245,
#  'nih': 30247,
#  'ogyris': 30249,
#  'omiza': 30250,
#  'organa': 30251,
#  'turgana': 30251,
#  'pantyene': 30254,
#  'parikane': 30255,
#  'parsika m.': 30256,
#  'poura': 30258,
#  'pushang': 30259,
#  'rogana': 30263,
#  'saganos': 30267,
#  'salaros': 30268,
#  'salmous': 30269,
#  'semiramis m.': 30270,
#  'sidodone': 30271,
#  'sigana': 30272,
#  'soxotai': 30273,
#  'talmena': 30275,
#  'teisa': 30277,
#  'zetis': 30279,
#  'zorambos': 30280,
#  'ad sava municipium': 305024,
#  'alpes numidicae': 305028,
#  'ampsaga': 305029,
#  'amsaga': 305029,
#  'aquae thibilitanae': 305030,
#  'assarath': 305031,
#  'astora': 305032,
#  'asuccuris': 305033,
#  'azimacia': 305034,
#  'castellum arsacalitanum': 305043,
#  'castellum aurelianense antoninianense': 305044,
#  'caput saltus horreorum pardalarii': 305044,
#  'castellum caldis': 305045,
#  'castellum dianense': 305046,
#  'castellum elefantum': 305047,
#  'castellum fabatianum': 305048,
#  'castellum gurolense': 305049,
#  'castellum mastarense': 305050,
#  'castellum subzuaritanum': 305053,
#  'castellum thib(...)': 305054,
#  'castellum turrense': 305055,
#  'kastellum matidiae': 305055,
#  'castellum vartan(...)': 305056,
#  'castellum zugal': 305057,
#  'celtianis': 305058,
#  'castellum celtianum': 305058,
#  'centenarium aqua frigida': 305059,
#  'chitouai': 305061,
#  'chullu': 305063,
#  'cirta': 305064,
#  'bagneaux megalith': 319068505,
#  'dolmen de bagneux': 319068505,
#  'nóaros': 377811335,
#  'arcipelago toscano': 490307091,
#  'bethela': 260940008,
#  'bethega': 260940008,
#  'kasta tomb': 864330772,
#  'tymbos kasta': 864330772,
#  'curiae veteres': 345477553,
#  'west house': 593460161,
#  'grave circle b': 593460162,
#  'portara': 593460163,
#  'çatal höyük': 483473194,
#  'çatal hüyük': 483473194,
#  'koukonesi': 645204823,
#  'dispilio': 471781651,
#  'oratory of phalaris': 946753455,
#  'oratorio di falaride': 946753455,
#  'teatro di marcello': 300583267,
#  'theatrum marcelli': 300583267,
#  'theater of marcellus': 300583267,
#  'santi giovanni e paolo': 267702570,
#  'clivus scauri': 267702571,
#  'basilica di san clemente': 865664297,
#  'basilica of san clemente al laterano': 865664297,
#  'mures': 378409584,
#  'ianiculum': 430827518,
#  'ianouklos': 430827518,
#  'templum claudii': 86419549,
#  'templum divi claudii': 86419549,
#  'felignates': 10993281,
#  'tel yoqne‘am': 180354033,
#  'caymont': 180354033,
#  'tell qamun': 180354033,
#  'saḥāb': 426595172,
#  'barah': 914118847,
#  'kenk boğazı': 842949950,
#  'theatrum pompei': 541950317,
#  'theatrum marmoreum': 541950317,
#  'teatro di pompeo': 541950317,
#  'theater of pompey': 541950317,
#  'theatrum magnum': 541950317,
#  'theatrum pompeianum': 541950317,
#  'maroni vournes': 380086882,
#  'le canet': 140546,
#  'montcaret': 140548,
#  'latresne': 140553,
#  'sainte-colombe': 140560,
#  'loupiac': 140572,
#  'alevernacum': 141942,
#  'antobroges': 141943,
#  'bagidone': 141946,
#  'briouates limen': 141947,
#  'canbidobrenum': 141949,
#  'clausetia': 141950,
#  'cuticiacum': 141951,
#  'fexitoialum': 141953,
#  'gracina': 141955,
#  'lauterna': 141957,
#  'pastoriacum': 141959,
#  'primuliacum': 141960,
#  'pontiniacus': 141961,
#  'vibriacum': 141964,
#  'vosidum': 141965,
#  'plotai': 142847211,
#  'plotae': 142847211,
#  'strophadeus': 142847211,
#  'ad ermum': 147982,
#  'aemines': 147984,
#  'agatha': 147985,
#  'agde': 147985,
#  'albici': 147987,
#  'allègre-les-fumades': 147989,
#  'ambrussum': 147990,
#  'pont-ambroix (ambrussum)': 147990,
#  'anatilii': 147991,
#  'andusia': 147992,
#  'anduze': 147992,
#  'apta iulia': 147993,
#  'aramo': 147995,
#  'arandunum': 147996,
#  'araura': 147997,
#  'cessero': 147997,
#  'saint-thibéry': 147997,
#  'cesse rone': 147997,
#  'arauris': 147998,
#  'avatici': 148003,
#  'avennio': 148004,
#  'avignon': 148004,
#  'balaruc-les-bains': 148007,
#  'notre-dame de beauregard': 148018,
#  'bellintum': 148019,
#  'blasco': 148020,
#  'ile de brescou': 148020,
#  'briginnum': 148024,
#  'brugetia': 148025,
#  'cabellio': 148027,
#  'cavaillon': 148027,
#  'calcaria solarium': 148028,
#  "laudun-l'ardoise": 148030,
#  'campi lapidei': 148032,
#  'carpentorate': 148036,
#  'carpentras': 148036,
#  'carbantorate meminorum': 148036,
#  'carsicis': 148037,
#  'castellas de rognac': 148038,
#  'nages': 148039,
#  'catuiacia': 148041,
#  'citharista': 148048,
#  'col. aquae sextiae': 148053,
#  'col. iulia augusta aquae sextiae': 148053,
#  'aix-en-provence': 148053,
#  'col. arausio': 148054,
#  'col. firma iulia arausio secundanorum': 148054,
#  'orange': 148054,
#  'col. baeterrae': 148056,
#  'col. victrix iulia paterna': 148056,
#  'béziers': 148056,
#  'la condoumine': 148058,
#  'cypresseta': 148065,
#  'dexivates': 148067,
#  'dilis': 148068,
#  'druentia': 148069,
#  'elisykoi': 148071,
#  'entremont': 148073,
#  'ernaginum': 148074,
#  'forum domitii': 148081,
#  'montbazin': 148081,
#  'frontiana': 148086,
#  'gallicum mare': 148089,
#  'gargarius': 148091,
#  'saint-vincent': 148092,
#  'glanum': 148093,
#  'gradus massilitanorum': 148094,
#  'hispaniense ostium': 148099,
#  'immadrae': 148101,
#  'incarus': 148102,
#  'lansargues': 148105,
#  'lattara': 148107,
#  'lattes': 148107,
#  'ledus': 148110,
#  'lettino': 148112,
#  'libica ora': 148113,
#  'liria': 148116,
#  'lombren': 148117,
#  'longostaletes': 148118,
#  'louerion m.': 148119,
#  'luteva': 148121,
#  'civ. lutevensium': 148121,
#  'lodève': 148121,
#  'magalona': 148123,
#  'massilia': 148127,
#  'marseille': 148127,
#  'massalía': 148127,
#  'massalioticum ostium': 148128,
#  'serre mouressipe': 148131,
#  'memini': 148132,
#  'mesua': 148133,
#  'mèze': 148133,
#  'metapinum ostium': 148134,
#  'puech de montfau': 148136,
#  'murviel-lés-montpellier': 148138,
#  'nemausus': 148142,
#  'nîmes': 148142,
#  'nemausos': 148142,
#  'orga fons': 148148,
#  'orbis': 148149,
#  'ovidis': 148150,
#  'pisavi': 148157,
#  'piscenae': 148158,
#  'pons aerarius': 148160,
#  'rhodanousia': 148167,
#  'espeyran': 148167,
#  'rhodanus': 148168,
#  'la roque': 148170,
#  'roque de vif': 148171,
#  'roquepertuse': 148174,
#  'saint-blaise': 148178,
#  'loupian': 148180,
#  'salyes': 148194,
#  'segobrigii': 148197,
#  'setius m.': 148201,
#  'sextantio': 148202,
#  'substantion': 148202,
#  'statumae': 148205,
#  'stomalimne': 148206,
#  'mastramela stagnum': 148206,
#  'volcarum stagna': 148211,
#  'tedusia': 148213,
#  'tericiae': 148215,
#  'mouriès': 148215,
#  'theline': 148217,
#  'col. arelate': 148217,
#  'col. iulia paterna sextanorum arelate': 148217,
#  'arles': 148217,
#  'traiectum rhodani': 148218,
#  'tricores': 148219,
#  'ucetia': 148222,
#  'uzès': 148222,
#  'ugernum': 148223,
#  'beaucaire': 148223,
#  'ura fons': 148224,
#  'vallis clara': 148226,
#  'varatunnum': 148227,
#  'vasio': 148228,
#  'vaison-la-romaine': 148228,
#  'vatrute': 148229,
#  'vieille cité': 148229,
#  'villevieille': 148235,
#  'vindalium': 148236,
#  'vindasca': 148237,
#  'vindelicus': 148238,
#  'soulgas': 148238,
#  'vintur m.': 148239,
#  'virinnae': 148240,
#  'volcae arecomici': 148242,
#  'vulgientes': 148244,
#  'pont du gard': 149496,
#  'albaugousta': 151759,
#  'anatilia': 151761,
#  'budenicum': 151764,
#  'caenica': 151766,
#  'caenicenses': 151766,
#  'comani': 151768,
#  'coriossedum': 151769,
#  'crindavinus portus': 151770,
#  'elykokoi': 151772,
#  'kyrene': 151776,
#  'mastramela': 151778,
#  'metina': 151779,
#  'samnaga': 151783,
#  'samnagenses': 151783,
#  'sekoanos': 151784,
#  'zao pr.': 151786,
#  'attagus': 152512,
#  'bergine': 152513,
#  'besara': 152514,
#  'cecylistrium': 152515,
#  'cinorus': 152516,
#  'classius': 152517,
#  'heledus': 152518,
#  'mansa': 152519,
#  'mastrabala': 152520,
#  'naustalo': 152521,
#  'nearchi': 152522,
#  'oranus': 152523,
#  'polygium': 152524,
#  'thyrius': 152525,
#  'ad horrea': 157798,
#  'tourves': 157799,
#  'alaunium': 157800,
#  'albium intimilium': 157802,
#  'album intimilium': 157802,
#  'albintimilium': 157802,
#  'albion intemelion': 157802,
#  'bintimilio': 157802,
#  'victimilium': 157802,
#  'vintimilium': 157802,
#  'album ingaunum': 157803,
#  'albingaunum': 157803,
#  'alconis': 157804,
#  'alebaece reiorum apollinarium': 157805,
#  'apollinaris reiorum': 157805,
#  'riez': 157805,
#  'anao': 157810,
#  'anteae': 157811,
#  'draguignan': 157811,
#  'antipolis': 157812,
#  'antibes': 157812,
#  'apron': 157814,
#  'argenteus': 157815,
#  'athenopolis': 157816,
#  'avisio': 157817,
#  'bodiontici': 157822,
#  'borma': 157824,
#  'brigomagus': 157827,
#  'camactulici': 157831,
#  'cemenelum': 157834,
#  'cimiez': 157834,
#  'col. forum iulii': 157836,
#  'fréjus': 157836,
#  ...}

# %%
x = []
x.append(3,[3,6])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-2a8835668002> in <module>()
#       1 x = []
# ----> 2 x.append(3,[3,6])
#
# TypeError: append() takes exactly one argument (2 given)

# %%
x
# Out:
# [[3, [3, 6]]]
